# %% [markdown]
# # Problem definition
#
# Earthquakes are killing countless people. I was especially moved when we lost lots of loved ones in the 2023 Turkey earthquake. Including our beloved Aliye Varoglu. Therefore, I would like to dedicate this study to her.
#
# I wonder if we could forecast earthquakes based on astrology.
#
# If we are able to foresee earthquakes, we can save countless lives.

# %% [markdown]
# <hr>

# %% [markdown]
# # Data
#
# We need two data sources: Earthquake statistics and astrology values on earthquake days.
#
# Initial structured earthquake data is available on https://data.humdata.org/dataset/catalog-of-earthquakes1970-2014 .
#
# Astrology values can be calculated in a Python library called Kerykeion: https://pypi.org/project/kerykeion/ .

# %% [markdown]
# ## Load earthquake CSV

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df_eq = pd.read_csv("earthquakes1970-2014.csv")
df_eq.head()
# Out:
#                  DateTime  Latitude  Longitude  ...  RMS  Source       EventID
# 0  1970/01/04 17:00:40.20    24.139    102.503  ...  0.0     NEI  1.970010e+09
# 1  1970/01/06 05:35:51.80    -9.628    151.458  ...  0.0     NEI  1.970011e+09
# 2  1970/01/08 17:12:39.10   -34.741    178.568  ...  0.0     NEI  1.970011e+09
# 3  1970/01/10 12:07:08.60     6.825    126.737  ...  0.0     NEI  1.970011e+09
# 4  1970/01/16 08:05:39.00    60.280   -152.660  ...  NaN      AK           NaN
#
# [5 rows x 12 columns]

# %%
df_eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5304 entries, 0 to 5303
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DateTime    5304 non-null   object
#  1   Latitude    5304 non-null   float64
#  2   Longitude   5304 non-null   float64
#  3   Depth       5304 non-null   float64
#  4   Magnitude   5304 non-null   float64
#  5   MagType     5304 non-null   object
#  6   NbStations  5250 non-null   float64
#  7   Gap         172 non-null    float64
#  8   Distance    170 non-null    float64
#  9   RMS         5264 non-null   float64
#  10  Source      5304 non-null   object
#  11  EventID     5242 non-null   float64
# dtypes: float64(9), object(3)
# memory usage: 497.4+ KB

# %%
df_eq.isna().sum()
# Out:
# DateTime         0
# Latitude         0
# Longitude        0
# Depth            0
# Magnitude        0
# MagType          0
# NbStations      54
# Gap           5132
# Distance      5134
# RMS             40
# Source           0
# EventID         62
# dtype: int64

# %% [markdown]
# ## Drop unnecessary columns

# %%
df_eq.drop(columns=["NbStations", 
                    "Gap", 
                    "Distance",
                    "RMS",
                    "EventID",
                    "Depth",
                    "MagType",
                    "Source"],
          inplace=True)

# %%
df_eq.head()
# Out:
#                  DateTime  Latitude  Longitude  Magnitude
# 0  1970/01/04 17:00:40.20    24.139    102.503        7.5
# 1  1970/01/06 05:35:51.80    -9.628    151.458        6.2
# 2  1970/01/08 17:12:39.10   -34.741    178.568        6.1
# 3  1970/01/10 12:07:08.60     6.825    126.737        6.1
# 4  1970/01/16 08:05:39.00    60.280   -152.660        6.0

# %% [markdown]
# ## Split date / time

# %%
df_eq2 = df_eq.copy()
df_eq2["Year"] = df_eq2["DateTime"].str[:4].astype(int)
df_eq2["Month"] = df_eq2["DateTime"].str[5:7].astype(int)
df_eq2["Day"] = df_eq2["DateTime"].str[8:10].astype(int)
df_eq2["Hour"] = df_eq2["DateTime"].str[11:13].astype(int)
df_eq2["Minute"] = df_eq2["DateTime"].str[14:16].astype(int)
df_eq2.drop(columns=["DateTime"], inplace=True)
df_eq2.head()
# Out:
#    Latitude  Longitude  Magnitude  Year  Month  Day  Hour  Minute
# 0    24.139    102.503        7.5  1970      1    4    17       0
# 1    -9.628    151.458        6.2  1970      1    6     5      35
# 2   -34.741    178.568        6.1  1970      1    8    17      12
# 3     6.825    126.737        6.1  1970      1   10    12       7
# 4    60.280   -152.660        6.0  1970      1   16     8       5

# %% [markdown]
# ## Add a column indicating a significant earthquake

# %%
df_eq2["BigEarthquake"] = 1
df_eq2.head()
# Out:
#    Latitude  Longitude  Magnitude  Year  ...  Day  Hour  Minute  BigEarthquake
# 0    24.139    102.503        7.5  1970  ...    4    17       0              1
# 1    -9.628    151.458        6.2  1970  ...    6     5      35              1
# 2   -34.741    178.568        6.1  1970  ...    8    17      12              1
# 3     6.825    126.737        6.1  1970  ...   10    12       7              1
# 4    60.280   -152.660        6.0  1970  ...   16     8       5              1
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Delete insignificant earthquakes from the list

# %%
a1 = len(df_eq2[df_eq2["Magnitude"] >= 1])
a2 = len(df_eq2[df_eq2["Magnitude"] >= 2])
a3 = len(df_eq2[df_eq2["Magnitude"] >= 3])
a4 = len(df_eq2[df_eq2["Magnitude"] >= 4])
a5 = len(df_eq2[df_eq2["Magnitude"] >= 5])
a6 = len(df_eq2[df_eq2["Magnitude"] >= 6])
a7 = len(df_eq2[df_eq2["Magnitude"] >= 7])
print(a1, a2, a3, a4, a5, a6, a7)
# Out:
# 5304 5304 5304 5304 5304 5304 533

# %% [markdown]
# All seem to be big, not much to do here

# %% [markdown]
# ## 💾 Save current cleansed dataset

# %%
df_eq2.to_csv("earthquakes1970-2014-2.csv", index=False)

# %% [markdown]
# ## Fill dataset with random entries where an earthquake did not happen

# %% [markdown]
# Main generation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df_eq2 = pd.read_csv("earthquakes1970-2014-2.csv")
df_eq2.head()
# Out:
#    Latitude  Longitude  Magnitude  Year  Month  Day  Hour  Minute  \
# 0    24.139    102.503        7.5  1970      1    4    17       0
# 1    -9.628    151.458        6.2  1970      1    6     5      35
# 2   -34.741    178.568        6.1  1970      1    8    17      12
# 3     6.825    126.737        6.1  1970      1   10    12       7
# 4    60.280   -152.660        6.0  1970      1   16     8       5
#
#    BigEarthquake
# 0              1
# 1              1
# 2              1
# 3              1
# 4              1

# %%
min_lat = df_eq2["Latitude"].min()
max_lat = df_eq2["Latitude"].max()
min_lon = df_eq2["Longitude"].min()
max_lon = df_eq2["Longitude"].max()
min_year = df_eq2["Year"].min()
max_year = df_eq2["Year"].max()

min_lat, max_lat, min_lon, max_lon, min_year, max_year
# Out:
# (-66.44799999999991, 84.94799999999991, -179.989, 179.997999999999, 1970, 2014)

# %%
len(df_eq2)
# Out:
# 5304

# %%
import random
import calendar

def get_random_day(year, month):
  days_in_month = calendar.monthrange(year, month)[1]
  random_day = random.randint(1, days_in_month)
  return random_day

# %%
def does_df_have_entry_on_day(year, month, day):
    rows = df_eq2.query(f"Year=={year} and Month=={month} and Day=={day}")
    return len(rows) > 0

def does_df_have_entry_on_time(year, month, day, hour, minute):
    rows = df_eq2.query(f"Year=={year} and Month=={month} and Day=={day} and Hour=={hour} and Minute=={minute}")
    return len(rows) > 0

# %%
import random

new_df = df_eq2.copy()
target_entry_count = len(df_eq2) * 30
while len(new_df) < target_entry_count:
    random_year = random.randint(min_year, max_year)
    random_month = random.randint(1, 12)
    random_day = get_random_day(random_year, random_month)
    random_hour = random.randint(0, 23)
    random_minute = random.randint(0, 59)
    
    #if does_df_have_entry_on_time(random_year, random_month, random_day, random_hour, random_minute):
    #    continue
    
    random_lat = random.uniform(min_lat, max_lat)
    random_lon = random.uniform(min_lon, max_lon)
    
    new_entry = {
        "Latitude": random_lat,
        "Longitude": random_lon,
        "Magnitude": 0,
        "Year": random_year,
        "Month": random_month,
        "Day": random_day,
        "Hour": random_hour,
        "Minute": random_minute,
        "BigEarthquake": 0
    }
    
    new_df = pd.concat([pd.DataFrame(new_entry, index=[0]),new_df.loc[:]]).reset_index(drop=True)

# %%
new_df.head()
# Out:
#     Latitude   Longitude  Magnitude  Year  Month  Day  Hour  Minute  \
# 0 -36.010840   75.813176        0.0  2004      3   13     8      34
# 1  75.182840  147.876041        0.0  1985      2   13    21      33
# 2   2.812124  -69.186252        0.0  1987      1   19    13      11
# 3  57.590868   58.496766        0.0  2007      5    5     1      29
# 4  61.617633   27.608128        0.0  1989      4   22    18      30
#
#    BigEarthquake
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %% [markdown]
# Remove non-earthquake data from days where a major earthquake happened

# %%
tmp = new_df.copy()

for index, row in df_eq2.iterrows():
    tmp = tmp.drop(tmp[(tmp["Year"] == row["Year"]) &
                       (tmp["Month"] == row["Month"]) &
                       (tmp["Day"] == row["Day"]) &
                       (tmp["BigEarthquake"] == 0)
                      ].index)
    
len(new_df), len(tmp)
# Out:
# (159120, 120518)

# %% [markdown]
# ## 💾 Save dataset with random entries

# %%
tmp.to_csv("earthquakes1970-2014-2b.csv", index=False)

# %% [markdown]
# ## Using Kerykeion, add astrological values to the dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df_eq2 = pd.read_csv("earthquakes1970-2014-2b.csv")
df_eq2.head()
# Out:
#     Latitude   Longitude  Magnitude  Year  Month  Day  Hour  Minute  \
# 0 -36.010840   75.813176        0.0  2004      3   13     8      34
# 1  75.182840  147.876041        0.0  1985      2   13    21      33
# 2   2.812124  -69.186252        0.0  1987      1   19    13      11
# 3  61.617633   27.608128        0.0  1989      4   22    18      30
# 4  -6.718776 -108.447335        0.0  1975      8    5     3       8
#
#    BigEarthquake
# 0              0
# 1              0
# 2              0
# 3              0
# 4              0

# %%
from kerykeion import KrInstance

df_eq3 = df_eq2.copy()

new_cols = {}

for row in df_eq3.iterrows():
    entry = row[1]
    try:
        astro = KrInstance("dummy", 
                           int(entry.Year), 
                           int(entry.Month), 
                           int(entry.Day), 
                           int(entry.Hour), 
                           int(entry.Minute), 
                           lng=entry.Longitude, 
                           lat=entry.Latitude,
                           city="dummy",
                           nation="dummy")
    except Exception:
        assert entry.BigEarthquake == 0
        hour = entry.Hour + 3
        astro = KrInstance("dummy", 
                           int(entry.Year), 
                           int(entry.Month), 
                           int(entry.Day), 
                           int(hour), 
                           int(entry.Minute), 
                           lng=entry.Longitude, 
                           lat=entry.Latitude,
                           city="dummy",
                           nation="dummy")
    
    for planet in astro.planets_list:
        for key, val in planet:
            if key == "name":
                planet_name = val
                continue
            col_name = f"{planet_name} {key}"
            if col_name not in new_cols:
                new_cols[col_name] = []
            new_cols[col_name].append(val)
    
    for house in astro.houses_list:
        for key, val in house:
            if key == "name":
                house_name = val
                continue
            col_name = f"{house_name} {key}"
            if col_name not in new_cols:
                new_cols[col_name] = []
            new_cols[col_name].append(val)
    
for key in new_cols:
    df_eq3[key] = new_cols[key]
    
df_eq3.head()
# Out:
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_77673/1353048281.py:55: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df_eq3[key] = new_cols[key]
#     Latitude   Longitude  Magnitude  Year  Month  Day  Hour  Minute  \
# 0 -36.010840   75.813176        0.0  2004      3   13     8      34
# 1  75.182840  147.876041        0.0  1985      2   13    21      33
# 2   2.812124  -69.186252        0.0  1987      1   19    13      11
# 3  61.617633   27.608128        0.0  1989      4   22    18      30
# 4  -6.718776 -108.447335        0.0  1975      8    5     3       8
#
#    BigEarthquake Sun quality  ... Twelfth House quality Twelfth House element  \
# 0              0     Mutable  ...               Mutable                 Water
# 1              0       Fixed  ...               Mutable                 Earth
# 2              0    Cardinal  ...              Cardinal                  Fire
# 3              0       Fixed  ...               Mutable                 Earth
# 4              0       Fixed  ...               Mutable                   Air
#
#    Twelfth House sign  Twelfth House sign_num  Twelfth House position  \
# 0                 Pis                      11               29.409324
# 1                 Vir                       5               19.037110
# 2                 Ari                       0               24.389663
# 3                 Vir                       5               24.179166
# 4                 Gem                       2                2.209341
#
#   Twelfth House abs_pos Twelfth House emoji Twelfth House point_type  \
# 0            359.409324                  ♓️                    House
# 1            169.037110                  ♍️                    House
# 2             24.389663                  ♈️                    House
# 3            174.179166                  ♍️                    House
# 4             62.209341                  ♊️                    House
#
#    Twelfth House house Twelfth House retrograde
# 0                 None                     None
# 1                 None                     None
# 2                 None                     None
# 3                 None                     None
# 4                 None                     None
#
# [5 rows x 249 columns]

# %% [markdown]
# ## 💾 Save dataset

# %%
df_eq3.to_csv("earthquakes1970-2014-3b.csv", index=False)

# %% [markdown]
# ## 💾 Drop useless columns and save dataset

# %%
df_eq4 = pd.read_csv("earthquakes1970-2014-3b.csv")
df_eq4 = df_eq4[df_eq4.columns.drop(list(df_eq4.filter(regex='House house')))] # Null
df_eq4 = df_eq4[df_eq4.columns.drop(list(df_eq4.filter(regex='House retrograde')))] # Null
df_eq4 = df_eq4[df_eq4.columns.drop(list(df_eq4.filter(regex='emoji')))] # Useless
df_eq4.to_csv("earthquakes1970-2014-4b.csv", index=False)

# %% [markdown]
# <hr>

# %% [markdown]
# # Evaluation
#
# My initial goal is to surpass an initial accuracy of 50%. If we can guess the earthquake possibility on a given location & day over 50%, this would definitely be a project worth chasing. Any lower value could still be significant, as scientists today don't have a concrete way of predicting earthquakes at all.
#
# I will obviously run the model on training / test datasets, but will also try to predict future / upcoming earthquakes.
#
# If I get good results; it makes sense to let the world know as soon as possible, as it can save lives. But I also need concrete predictions so that the world believes my success. Ethical dilemma - but I don't know what else to do in such a noisy world to make my success heard.

# %% [markdown]
# <hr>

# %% [markdown]
# # Features

# %% [markdown]
# ## Convert features to numbers as needed

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("earthquakes1970-2014-4b.csv")

# %%
pd.options.display.max_rows = 4000
df.dtypes
# Out:
# Latitude                     float64
# Longitude                    float64
# Magnitude                    float64
# Year                           int64
# Month                          int64
# Day                            int64
# Hour                           int64
# Minute                         int64
# BigEarthquake                  int64
# Sun quality                   object
# Sun element                   object
# Sun sign                      object
# Sun sign_num                   int64
# Sun position                 float64
# Sun abs_pos                  float64
# Sun point_type                object
# Sun house                     object
# Sun retrograde                  bool
# Moon quality                  object
# Moon element                  object
# Moon sign                     object
# Moon sign_num                  int64
# Moon position                float64
# Moon abs_pos                 float64
# Moon point_type               object
# Moon house                    object
# Moon retrograde                 bool
# Mercury quality               object
# Mercury element               object
# Mercury sign                  object
# Mercury sign_num               int64
# Mercury position             float64
# Mercury abs_pos              float64
# Mercury point_type            object
# Mercury house                 object
# Mercury retrograde              bool
# Venus quality                 object
# Venus element                 object
# Venus sign                    object
# Venus sign_num                 int64
# Venus position               float64
# Venus abs_pos                float64
# Venus point_type              object
# Venus house                   object
# Venus retrograde                bool
# Mars quality                  object
# Mars element                  object
# Mars sign                     object
# Mars sign_num                  int64
# Mars position                float64
# Mars abs_pos                 float64
# Mars point_type               object
# Mars house                    object
# Mars retrograde                 bool
# Jupiter quality               object
# Jupiter element               object
# Jupiter sign                  object
# Jupiter sign_num               int64
# Jupiter position             float64
# Jupiter abs_pos              float64
# Jupiter point_type            object
# Jupiter house                 object
# Jupiter retrograde              bool
# Saturn quality                object
# Saturn element                object
# Saturn sign                   object
# Saturn sign_num                int64
# Saturn position              float64
# Saturn abs_pos               float64
# Saturn point_type             object
# Saturn house                  object
# Saturn retrograde               bool
# Uranus quality                object
# Uranus element                object
# Uranus sign                   object
# Uranus sign_num                int64
# Uranus position              float64
# Uranus abs_pos               float64
# Uranus point_type             object
# Uranus house                  object
# Uranus retrograde               bool
# Neptune quality               object
# Neptune element               object
# Neptune sign                  object
# Neptune sign_num               int64
# Neptune position             float64
# Neptune abs_pos              float64
# Neptune point_type            object
# Neptune house                 object
# Neptune retrograde              bool
# Pluto quality                 object
# Pluto element                 object
# Pluto sign                    object
# Pluto sign_num                 int64
# Pluto position               float64
# Pluto abs_pos                float64
# Pluto point_type              object
# Pluto house                   object
# Pluto retrograde                bool
# Mean_Node quality             object
# Mean_Node element             object
# Mean_Node sign                object
# Mean_Node sign_num             int64
# Mean_Node position           float64
# Mean_Node abs_pos            float64
# Mean_Node point_type          object
# Mean_Node house               object
# Mean_Node retrograde            bool
# True_Node quality             object
# True_Node element             object
# True_Node sign                object
# True_Node sign_num             int64
# True_Node position           float64
# True_Node abs_pos            float64
# True_Node point_type          object
# True_Node house               object
# True_Node retrograde            bool
# First House quality           object
# First House element           object
# First House sign              object
# First House sign_num           int64
# First House position         float64
# First House abs_pos          float64
# First House point_type        object
# Second House quality          object
# Second House element          object
# Second House sign             object
# Second House sign_num          int64
# Second House position        float64
# Second House abs_pos         float64
# Second House point_type       object
# Third House quality           object
# Third House element           object
# Third House sign              object
# Third House sign_num           int64
# Third House position         float64
# Third House abs_pos          float64
# Third House point_type        object
# Fourth House quality          object
# Fourth House element          object
# Fourth House sign             object
# Fourth House sign_num          int64
# Fourth House position        float64
# Fourth House abs_pos         float64
# Fourth House point_type       object
# Fifth House quality           object
# Fifth House element           object
# Fifth House sign              object
# Fifth House sign_num           int64
# Fifth House position         float64
# Fifth House abs_pos          float64
# Fifth House point_type        object
# Sixth House quality           object
# Sixth House element           object
# Sixth House sign              object
# Sixth House sign_num           int64
# Sixth House position         float64
# Sixth House abs_pos          float64
# Sixth House point_type        object
# Seventh House quality         object
# Seventh House element         object
# Seventh House sign            object
# Seventh House sign_num         int64
# Seventh House position       float64
# Seventh House abs_pos        float64
# Seventh House point_type      object
# Eighth House quality          object
# Eighth House element          object
# Eighth House sign             object
# Eighth House sign_num          int64
# Eighth House position        float64
# Eighth House abs_pos         float64
# Eighth House point_type       object
# Ninth House quality           object
# Ninth House element           object
# Ninth House sign              object
# Ninth House sign_num           int64
# Ninth House position         float64
# Ninth House abs_pos          float64
# Ninth House point_type        object
# Tenth House quality           object
# Tenth House element           object
# Tenth House sign              object
# Tenth House sign_num           int64
# Tenth House position         float64
# Tenth House abs_pos          float64
# Tenth House point_type        object
# Eleventh House quality        object
# Eleventh House element        object
# Eleventh House sign           object
# Eleventh House sign_num        int64
# Eleventh House position      float64
# Eleventh House abs_pos       float64
# Eleventh House point_type     object
# Twelfth House quality         object
# Twelfth House element         object
# Twelfth House sign            object
# Twelfth House sign_num         int64
# Twelfth House position       float64
# Twelfth House abs_pos        float64
# Twelfth House point_type      object
# dtype: object

# %%
def preprocess_data(dfx):
    df = dfx.copy()
    
    for label, content in df.items():
        if pd.api.types.is_string_dtype(content):
            df[label] = content.astype("category").cat.as_ordered()
        if pd.api.types.is_bool_dtype(content):
            df[label] = (df[label] == True).astype(int)
            
    return df

# %%
tmp = preprocess_data(df)
tmp.dtypes
# Out:
# Latitude                      float64
# Longitude                     float64
# Magnitude                     float64
# Year                            int64
# Month                           int64
# Day                             int64
# Hour                            int64
# Minute                          int64
# BigEarthquake                   int64
# Sun quality                  category
# Sun element                  category
# Sun sign                     category
# Sun sign_num                    int64
# Sun position                  float64
# Sun abs_pos                   float64
# Sun point_type               category
# Sun house                    category
# Sun retrograde                  int64
# Moon quality                 category
# Moon element                 category
# Moon sign                    category
# Moon sign_num                   int64
# Moon position                 float64
# Moon abs_pos                  float64
# Moon point_type              category
# Moon house                   category
# Moon retrograde                 int64
# Mercury quality              category
# Mercury element              category
# Mercury sign                 category
# Mercury sign_num                int64
# Mercury position              float64
# Mercury abs_pos               float64
# Mercury point_type           category
# Mercury house                category
# Mercury retrograde              int64
# Venus quality                category
# Venus element                category
# Venus sign                   category
# Venus sign_num                  int64
# Venus position                float64
# Venus abs_pos                 float64
# Venus point_type             category
# Venus house                  category
# Venus retrograde                int64
# Mars quality                 category
# Mars element                 category
# Mars sign                    category
# Mars sign_num                   int64
# Mars position                 float64
# Mars abs_pos                  float64
# Mars point_type              category
# Mars house                   category
# Mars retrograde                 int64
# Jupiter quality              category
# Jupiter element              category
# Jupiter sign                 category
# Jupiter sign_num                int64
# Jupiter position              float64
# Jupiter abs_pos               float64
# Jupiter point_type           category
# Jupiter house                category
# Jupiter retrograde              int64
# Saturn quality               category
# Saturn element               category
# Saturn sign                  category
# Saturn sign_num                 int64
# Saturn position               float64
# Saturn abs_pos                float64
# Saturn point_type            category
# Saturn house                 category
# Saturn retrograde               int64
# Uranus quality               category
# Uranus element               category
# Uranus sign                  category
# Uranus sign_num                 int64
# Uranus position               float64
# Uranus abs_pos                float64
# Uranus point_type            category
# Uranus house                 category
# Uranus retrograde               int64
# Neptune quality              category
# Neptune element              category
# Neptune sign                 category
# Neptune sign_num                int64
# Neptune position              float64
# Neptune abs_pos               float64
# Neptune point_type           category
# Neptune house                category
# Neptune retrograde              int64
# Pluto quality                category
# Pluto element                category
# Pluto sign                   category
# Pluto sign_num                  int64
# Pluto position                float64
# Pluto abs_pos                 float64
# Pluto point_type             category
# Pluto house                  category
# Pluto retrograde                int64
# Mean_Node quality            category
# Mean_Node element            category
# Mean_Node sign               category
# Mean_Node sign_num              int64
# Mean_Node position            float64
# Mean_Node abs_pos             float64
# Mean_Node point_type         category
# Mean_Node house              category
# Mean_Node retrograde            int64
# True_Node quality            category
# True_Node element            category
# True_Node sign               category
# True_Node sign_num              int64
# True_Node position            float64
# True_Node abs_pos             float64
# True_Node point_type         category
# True_Node house              category
# True_Node retrograde            int64
# First House quality          category
# First House element          category
# First House sign             category
# First House sign_num            int64
# First House position          float64
# First House abs_pos           float64
# First House point_type       category
# Second House quality         category
# Second House element         category
# Second House sign            category
# Second House sign_num           int64
# Second House position         float64
# Second House abs_pos          float64
# Second House point_type      category
# Third House quality          category
# Third House element          category
# Third House sign             category
# Third House sign_num            int64
# Third House position          float64
# Third House abs_pos           float64
# Third House point_type       category
# Fourth House quality         category
# Fourth House element         category
# Fourth House sign            category
# Fourth House sign_num           int64
# Fourth House position         float64
# Fourth House abs_pos          float64
# Fourth House point_type      category
# Fifth House quality          category
# Fifth House element          category
# Fifth House sign             category
# Fifth House sign_num            int64
# Fifth House position          float64
# Fifth House abs_pos           float64
# Fifth House point_type       category
# Sixth House quality          category
# Sixth House element          category
# Sixth House sign             category
# Sixth House sign_num            int64
# Sixth House position          float64
# Sixth House abs_pos           float64
# Sixth House point_type       category
# Seventh House quality        category
# Seventh House element        category
# Seventh House sign           category
# Seventh House sign_num          int64
# Seventh House position        float64
# Seventh House abs_pos         float64
# Seventh House point_type     category
# Eighth House quality         category
# Eighth House element         category
# Eighth House sign            category
# Eighth House sign_num           int64
# Eighth House position         float64
# Eighth House abs_pos          float64
# Eighth House point_type      category
# Ninth House quality          category
# Ninth House element          category
# Ninth House sign             category
# Ninth House sign_num            int64
# Ninth House position          float64
# Ninth House abs_pos           float64
# Ninth House point_type       category
# Tenth House quality          category
# Tenth House element          category
# Tenth House sign             category
# Tenth House sign_num            int64
# Tenth House position          float64
# Tenth House abs_pos           float64
# Tenth House point_type       category
# Eleventh House quality       category
# Eleventh House element       category
# Eleventh House sign          category
# Eleventh House sign_num         int64
# Eleventh House position       float64
# Eleventh House abs_pos        float64
# Eleventh House point_type    category
# Twelfth House quality        category
# Twelfth House element        category
# Twelfth House sign           category
# Twelfth House sign_num          int64
# Twelfth House position        float64
# Twelfth House abs_pos         float64
# Twelfth House point_type     category
# dtype: object

# %%
tmp.head().T
# Out:
#                                         0             1               2  \
# Latitude                        -36.01084      75.18284        2.812124
# Longitude                       75.813176    147.876041      -69.186252
# Magnitude                             0.0           0.0             0.0
# Year                                 2004          1985            1987
# Month                                   3             2               1
# Day                                    13            13              19
# Hour                                    8            21              13
# Minute                                 34            33              11
# BigEarthquake                           0             0               0
# Sun quality                       Mutable         Fixed        Cardinal
# Sun element                         Water           Air           Earth
# Sun sign                              Pis           Aqu             Cap
# Sun sign_num                           11            10               9
# Sun position                    23.310369     25.346848        29.13052
# Sun abs_pos                    353.310369    325.346848       299.13052
# Sun point_type                     Planet        Planet          Planet
# Sun house                  Eleventh House   Fifth House     Ninth House
# Sun retrograde                          0             0               0
# Moon quality                      Mutable       Mutable         Mutable
# Moon element                         Fire          Fire           Earth
# Moon sign                             Sag           Sag             Vir
# Moon sign_num                           8             8               5
# Moon position                   19.226073     17.797703       21.086772
# Moon abs_pos                   259.226073    257.797703      171.086772
# Moon point_type                    Planet        Planet          Planet
# Moon house                   Eighth House   Third House     Fifth House
# Moon retrograde                         0             0               0
# Mercury quality                  Cardinal         Fixed           Fixed
# Mercury element                      Fire           Air             Air
# Mercury sign                          Ari           Aqu             Aqu
# Mercury sign_num                        0            10              10
# Mercury position                 2.269248     21.278901        3.738137
# Mercury abs_pos                  2.269248    321.278901      303.738137
# Mercury point_type                 Planet        Planet          Planet
# Mercury house               Twelfth House   Fifth House     Ninth House
# Mercury retrograde                      0             0               0
# Venus quality                       Fixed      Cardinal         Mutable
# Venus element                       Earth          Fire            Fire
# Venus sign                            Tau           Ari             Sag
# Venus sign_num                          1             0               8
# Venus position                    8.54723      9.997504       12.316619
# Venus abs_pos                    38.54723      9.997504      252.316619
# Venus point_type                   Planet        Planet          Planet
# Venus house                 Twelfth House   Sixth House     Sixth House
# Venus retrograde                        0             0               0
# Mars quality                        Fixed      Cardinal        Cardinal
# Mars element                        Earth          Fire            Fire
# Mars sign                             Tau           Ari             Ari
# Mars sign_num                           1             0               0
# Mars position                   25.030904      8.538502         7.85751
# Mars abs_pos                    55.030904      8.538502         7.85751
# Mars point_type                    Planet        Planet          Planet
# Mars house                    First House   Sixth House  Eleventh House
# Mars retrograde                         0             0               0
# Jupiter quality                   Mutable         Fixed         Mutable
# Jupiter element                     Earth           Air           Water
# Jupiter sign                          Vir           Aqu             Pis
# Jupiter sign_num                        5            10              11
# Jupiter position                12.752784      1.693954       20.816019
# Jupiter abs_pos                162.752784    301.693954      350.816019
# Jupiter point_type                 Planet        Planet          Planet
# Jupiter house                 Fifth House  Fourth House  Eleventh House
# Jupiter retrograde                      1             0               0
# Saturn quality                   Cardinal         Fixed         Mutable
# Saturn element                      Water         Water            Fire
# Saturn sign                           Can           Sco             Sag
# Saturn sign_num                         3             7               8
# Saturn position                  6.318193     27.735723        17.35913
# Saturn abs_pos                  96.318193    237.735723       257.35913
# Saturn point_type                  Planet        Planet          Planet
# Saturn house                 Second House  Second House   Seventh House
# Saturn retrograde                       0             0               0
# Uranus quality                    Mutable       Mutable         Mutable
# Uranus element                      Water          Fire            Fire
# Uranus sign                           Pis           Sag             Sag
# Uranus sign_num                        11             8               8
# Uranus position                  3.947748       17.3918       24.653988
# Uranus abs_pos                 333.947748      257.3918      264.653988
# Uranus point_type                  Planet        Planet          Planet
# Uranus house               Eleventh House   Third House   Seventh House
# Uranus retrograde                       0             0               0
# Neptune quality                     Fixed      Cardinal        Cardinal
# Neptune element                       Air         Earth           Earth
# Neptune sign                          Aqu           Cap             Cap
# Neptune sign_num                       10             9               9
# Neptune position                14.302024      2.940574        6.379731
# Neptune abs_pos                314.302024    272.940574      276.379731
# Neptune point_type                 Planet        Planet          Planet
# Neptune house                 Tenth House   Third House    Eighth House
# Neptune retrograde                      0             0               0
# Pluto quality                     Mutable         Fixed           Fixed
# Pluto element                        Fire         Water           Water
# Pluto sign                            Sag           Sco             Sco
# Pluto sign_num                          8             7               7
# Pluto position                  22.212432      4.729038        9.816309
# Pluto abs_pos                  262.212432    214.729038      219.816309
# Pluto point_type                   Planet        Planet          Planet
# Pluto house                  Eighth House   First House     Sixth House
# Pluto retrograde                        0             1               0
# Mean_Node quality                   Fixed         Fixed        Cardinal
# Mean_Node element                   Earth         Earth            Fire
# Mean_Node sign                        Tau           Tau             Ari
# Mean_Node sign_num                      1             1               0
# Mean_Node position              13.859818     22.812819       15.501342
# Mean_Node abs_pos               43.859818     52.812819       15.501342
# Mean_Node point_type               Planet        Planet          Planet
# Mean_Node house             Twelfth House  Eighth House  Eleventh House
# Mean_Node retrograde                    1             1               1
# True_Node quality                   Fixed         Fixed        Cardinal
# True_Node element                   Earth         Earth            Fire
# True_Node sign                        Tau           Tau             Ari
# True_Node sign_num                      1             1               0
# True_Node position              12.411178     22.787573       14.435463
# True_Node abs_pos               42.411178     52.787573       14.435463
# True_Node point_type               Planet        Planet          Planet
# True_Node house             Twelfth House  Eighth House  Eleventh House
# True_Node retrograde                    0             1               1
# First House quality                 Fixed      Cardinal         Mutable
# First House element                 Earth           Air             Air
# First House sign                      Tau           Lib             Gem
# First House sign_num                    1             6               2
# First House position            22.092609     12.703568        12.60998
# First House abs_pos             52.092609    192.703568        72.60998
# First House point_type              House         House           House
# Second House quality              Mutable         Fixed        Cardinal
# Second House element                  Air         Water           Water
# Second House sign                     Gem           Sco             Can
# Second House sign_num                   2             7               3
# Second House position           17.991541      8.940709        3.428539
# Second House abs_pos            77.991541    218.940709       93.428539
# Second House point_type             House         House           House
# Third House quality              Cardinal       Mutable        Cardinal
# Third House element                 Water          Fire           Water
# Third House sign                      Can           Sag             Can
# Third House sign_num                    3             8               3
# BigEarthquake                          0               0
# Sun quality                        Fixed           Fixed
# Sun element                        Earth            Fire
# Sun sign                             Tau             Leo
# Sun sign_num                           1               4
# Sun position                    2.756334       12.259509
# Sun abs_pos                    32.756334      132.259509
# Sun point_type                    Planet          Planet
# Sun house                  Seventh House    Second House
# Sun retrograde                         0               0
# Moon quality                       Fixed        Cardinal
# Moon element                       Water           Water
# Moon sign                            Sco             Can
# Moon sign_num                          7               3
# Moon position                  22.779093       12.157539
# Moon abs_pos                  232.779093      102.157539
# Moon point_type                   Planet          Planet
# Moon house                  Second House     First House
# Moon retrograde                        0               0
# Mercury quality                    Fixed           Fixed
# Mercury element                    Earth            Fire
# Mercury sign                         Tau             Leo
# Mercury sign_num                       1               4
# Mercury position               20.760125       16.541738
# Mercury abs_pos                50.760125      136.541738
# Mercury point_type                Planet          Planet
# Mercury house               Eighth House    Second House
# Mercury retrograde                     0               0
# Venus quality                      Fixed         Mutable
# Venus element                      Earth           Earth
# Venus sign                           Tau             Vir
# Venus sign_num                         1               5
# Venus position                  7.396919       11.696692
# Venus abs_pos                  37.396919      161.696692
# Venus point_type                  Planet          Planet
# Venus house                Seventh House     Third House
# Venus retrograde                       0               0
# Mars quality                     Mutable           Fixed
# Mars element                         Air           Earth
# Mars sign                            Gem             Tau
# Mars sign_num                          2               1
# Mars position                  26.135529       23.954396
# Mars abs_pos                   86.135529       53.954396
# Mars point_type                   Planet          Planet
# Mars house                   Ninth House  Eleventh House
# Mars retrograde                        0               0
# Jupiter quality                  Mutable        Cardinal
# Jupiter element                      Air            Fire
# Jupiter sign                         Gem             Ari
# Jupiter sign_num                       2               0
# Jupiter position                7.819676       24.554566
# Jupiter abs_pos                67.819676       24.554566
# Jupiter point_type                Planet          Planet
# Jupiter house               Eighth House  Eleventh House
# Jupiter retrograde                     0               0
# Saturn quality                  Cardinal        Cardinal
# Saturn element                     Earth           Water
# Saturn sign                          Cap             Can
# Saturn sign_num                        9               3
# Saturn position                 13.92757       25.160833
# Saturn abs_pos                 283.92757      115.160833
# Saturn point_type                 Planet          Planet
# Saturn house                 Third House     First House
# Saturn retrograde                      0               0
# Uranus quality                  Cardinal        Cardinal
# Uranus element                     Earth             Air
# Uranus sign                          Cap             Lib
# Uranus sign_num                        9               6
# Uranus position                 5.255822       28.726176
# Uranus abs_pos                275.255822      208.726176
# Uranus point_type                 Planet          Planet
# Uranus house                 Third House     Fifth House
# Uranus retrograde                      1               0
# Neptune quality                 Cardinal         Mutable
# Neptune element                    Earth            Fire
# Neptune sign                         Cap             Sag
# Neptune sign_num                       9               8
# Neptune position               12.362562        9.092788
# Neptune abs_pos               282.362562      249.092788
# Neptune point_type                Planet          Planet
# Neptune house                Third House     Sixth House
# Neptune retrograde                     1               1
# Pluto quality                      Fixed        Cardinal
# Pluto element                      Water             Air
# Pluto sign                           Sco             Lib
# Pluto sign_num                         7               6
# Pluto position                 14.116843        7.128052
# Pluto abs_pos                 224.116843      187.128052
# Pluto point_type                  Planet          Planet
# Pluto house                 Second House    Fourth House
# Pluto retrograde                       1               0
# Mean_Node quality                Mutable           Fixed
# Mean_Node element                  Water           Water
# Mean_Node sign                       Pis             Sco
# Mean_Node sign_num                    11               7
# Mean_Node position              1.860664       27.142666
# Mean_Node abs_pos             331.860664      237.142666
# Mean_Node point_type              Planet          Planet
# Mean_Node house              Fifth House     Fifth House
# Mean_Node retrograde                   1               1
# True_Node quality                Mutable           Fixed
# True_Node element                  Water           Water
# True_Node sign                       Pis             Sco
# True_Node sign_num                    11               7
# True_Node position              2.998212        28.05339
# True_Node abs_pos             332.998212       238.05339
# True_Node point_type              Planet          Planet
# True_Node house              Fifth House     Fifth House
# True_Node retrograde                   1               1
# First House quality             Cardinal        Cardinal
# First House element                  Air           Water
# First House sign                     Lib             Can
# First House sign_num                   6               3
# First House position           17.306054       10.131841
# First House abs_pos           197.306054      100.131841
# First House point_type             House           House
# Second House quality               Fixed        Cardinal
# Second House element               Water           Water
# Second House sign                    Sco             Can
# Second House sign_num                  7               3
# Second House position           13.95443       27.996366
# Second House abs_pos           223.95443      117.996366
# Second House point_type            House           House
# Third House quality              Mutable           Fixed
# Third House element                 Fire            Fire
# Third House sign                     Sag             Leo
# Third House sign_num                   8               4
# Third House position           15.718198       17.935821
# Third House abs_pos           255.718198      137.935821
# Third House point_type             House           House
# Fourth House quality            Cardinal         Mutable
# Fourth House element               Earth           Earth
# Fourth House sign                    Cap             Vir
# Fourth House sign_num                  9               5
# Fourth House position          21.330481       13.525382
# Fourth House abs_pos          291.330481      163.525382
# Fourth House point_type            House           House
# Fifth House quality                Fixed        Cardinal
# Fifth House element                  Air             Air
# Fifth House sign                     Aqu             Lib
# Fifth House sign_num                  10               6
# Fifth House position           25.424456       18.854461
# Fifth House abs_pos           325.424456      198.854461
# Fifth House point_type             House           House
# Sixth House quality              Mutable         Mutable
# Sixth House element                Water            Fire
# Sixth House sign                     Pis             Sag
# Sixth House sign_num                  11               8
# Sixth House position           24.179166        2.209341
# Sixth House abs_pos           354.179166      242.209341
# Sixth House point_type             House           House
# Seventh House quality           Cardinal        Cardinal
# Seventh House element               Fire           Earth
# Seventh House sign                   Ari             Cap
# Seventh House sign_num                 0               9
# Seventh House position         17.306054       10.131841
# Seventh House abs_pos          17.306054      280.131841
# Seventh House point_type           House           House
# Eighth House quality               Fixed        Cardinal
# Eighth House element               Earth           Earth
# Eighth House sign                    Tau             Cap
# Eighth House sign_num                  1               9
# Eighth House position           13.95443       27.996366
# Eighth House abs_pos            43.95443      297.996366
# Eighth House point_type            House           House
# Ninth House quality              Mutable           Fixed
# Ninth House element                  Air             Air
# Ninth House sign                     Gem             Aqu
# Ninth House sign_num                   2              10
# Ninth House position           15.718198       17.935821
# Ninth House abs_pos            75.718198      317.935821
# Ninth House point_type             House           House
# Tenth House quality             Cardinal         Mutable
# Tenth House element                Water           Water
# Tenth House sign                     Can             Pis
# Tenth House sign_num                   3              11
# Tenth House position           21.330481       13.525382
# Tenth House abs_pos           111.330481      343.525382
# Tenth House point_type             House           House
# Eleventh House quality             Fixed        Cardinal
# Eleventh House element              Fire            Fire
# Eleventh House sign                  Leo             Ari
# Eleventh House sign_num                4               0
# Eleventh House position        25.424456       18.854461
# Eleventh House abs_pos        145.424456       18.854461
# Eleventh House point_type          House           House
# Twelfth House quality            Mutable         Mutable
# Twelfth House element              Earth             Air
# Twelfth House sign                   Vir             Gem
# Twelfth House sign_num                 5               2
# Twelfth House position         24.179166        2.209341
# Twelfth House abs_pos         174.179166       62.209341
# Twelfth House point_type           House           House

# %%
tmp.to_csv("earthquakes1970-2014-5.csv", index=False)

# %% [markdown]
# ## Inspect if anything else is needed

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("earthquakes1970-2014-5.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120518 entries, 0 to 120517
# Columns: 201 entries, Latitude to Twelfth House point_type
# dtypes: bool(12), float64(51), int64(30), object(108)
# memory usage: 175.2+ MB

# %%
df.dtypes
# Out:
# Latitude                     float64
# Longitude                    float64
# Magnitude                    float64
# Year                           int64
# Month                          int64
# Day                            int64
# Hour                           int64
# Minute                         int64
# BigEarthquake                  int64
# Sun quality                   object
# Sun element                   object
# Sun sign                      object
# Sun sign_num                   int64
# Sun position                 float64
# Sun abs_pos                  float64
# Sun point_type                object
# Sun house                     object
# Sun retrograde                 int64
# Moon quality                  object
# Moon element                  object
# Moon sign                     object
# Moon sign_num                  int64
# Moon position                float64
# Moon abs_pos                 float64
# Moon point_type               object
# Moon house                    object
# Moon retrograde                int64
# Mercury quality               object
# Mercury element               object
# Mercury sign                  object
# Mercury sign_num               int64
# Mercury position             float64
# Mercury abs_pos              float64
# Mercury point_type            object
# Mercury house                 object
# Mercury retrograde             int64
# Venus quality                 object
# Venus element                 object
# Venus sign                    object
# Venus sign_num                 int64
# Venus position               float64
# Venus abs_pos                float64
# Venus point_type              object
# Venus house                   object
# Venus retrograde               int64
# Mars quality                  object
# Mars element                  object
# Mars sign                     object
# Mars sign_num                  int64
# Mars position                float64
# Mars abs_pos                 float64
# Mars point_type               object
# Mars house                    object
# Mars retrograde                int64
# Jupiter quality               object
# Jupiter element               object
# Jupiter sign                  object
# Jupiter sign_num               int64
# Jupiter position             float64
# Jupiter abs_pos              float64
# Jupiter point_type            object
# Jupiter house                 object
# Jupiter retrograde             int64
# Saturn quality                object
# Saturn element                object
# Saturn sign                   object
# Saturn sign_num                int64
# Saturn position              float64
# Saturn abs_pos               float64
# Saturn point_type             object
# Saturn house                  object
# Saturn retrograde              int64
# Uranus quality                object
# Uranus element                object
# Uranus sign                   object
# Uranus sign_num                int64
# Uranus position              float64
# Uranus abs_pos               float64
# Uranus point_type             object
# Uranus house                  object
# Uranus retrograde              int64
# Neptune quality               object
# Neptune element               object
# Neptune sign                  object
# Neptune sign_num               int64
# Neptune position             float64
# Neptune abs_pos              float64
# Neptune point_type            object
# Neptune house                 object
# Neptune retrograde             int64
# Pluto quality                 object
# Pluto element                 object
# Pluto sign                    object
# Pluto sign_num                 int64
# Pluto position               float64
# Pluto abs_pos                float64
# Pluto point_type              object
# Pluto house                   object
# Pluto retrograde               int64
# Mean_Node quality             object
# Mean_Node element             object
# Mean_Node sign                object
# Mean_Node sign_num             int64
# Mean_Node position           float64
# Mean_Node abs_pos            float64
# Mean_Node point_type          object
# Mean_Node house               object
# Mean_Node retrograde           int64
# True_Node quality             object
# True_Node element             object
# True_Node sign                object
# True_Node sign_num             int64
# True_Node position           float64
# True_Node abs_pos            float64
# True_Node point_type          object
# True_Node house               object
# True_Node retrograde           int64
# First House quality           object
# First House element           object
# First House sign              object
# First House sign_num           int64
# First House position         float64
# First House abs_pos          float64
# First House point_type        object
# Second House quality          object
# Second House element          object
# Second House sign             object
# Second House sign_num          int64
# Second House position        float64
# Second House abs_pos         float64
# Second House point_type       object
# Third House quality           object
# Third House element           object
# Third House sign              object
# Third House sign_num           int64
# Third House position         float64
# Third House abs_pos          float64
# Third House point_type        object
# Fourth House quality          object
# Fourth House element          object
# Fourth House sign             object
# Fourth House sign_num          int64
# Fourth House position        float64
# Fourth House abs_pos         float64
# Fourth House point_type       object
# Fifth House quality           object
# Fifth House element           object
# Fifth House sign              object
# Fifth House sign_num           int64
# Fifth House position         float64
# Fifth House abs_pos          float64
# Fifth House point_type        object
# Sixth House quality           object
# Sixth House element           object
# Sixth House sign              object
# Sixth House sign_num           int64
# Sixth House position         float64
# Sixth House abs_pos          float64
# Sixth House point_type        object
# Seventh House quality         object
# Seventh House element         object
# Seventh House sign            object
# Seventh House sign_num         int64
# Seventh House position       float64
# Seventh House abs_pos        float64
# Seventh House point_type      object
# Eighth House quality          object
# Eighth House element          object
# Eighth House sign             object
# Eighth House sign_num          int64
# Eighth House position        float64
# Eighth House abs_pos         float64
# Eighth House point_type       object
# Ninth House quality           object
# Ninth House element           object
# Ninth House sign              object
# Ninth House sign_num           int64
# Ninth House position         float64
# Ninth House abs_pos          float64
# Ninth House point_type        object
# Tenth House quality           object
# Tenth House element           object
# Tenth House sign              object
# Tenth House sign_num           int64
# Tenth House position         float64
# Tenth House abs_pos          float64
# Tenth House point_type        object
# Eleventh House quality        object
# Eleventh House element        object
# Eleventh House sign           object
# Eleventh House sign_num        int64
# Eleventh House position      float64
# Eleventh House abs_pos       float64
# Eleventh House point_type     object
# Twelfth House quality         object
# Twelfth House element         object
# Twelfth House sign            object
# Twelfth House sign_num         int64
# Twelfth House position       float64
# Twelfth House abs_pos        float64
# Twelfth House point_type      object
# dtype: object

# %%
df.isna().sum()
# Out:
# Latitude                     0
# Longitude                    0
# Magnitude                    0
# Year                         0
# Month                        0
# Day                          0
# Hour                         0
# Minute                       0
# BigEarthquake                0
# Sun quality                  0
# Sun element                  0
# Sun sign                     0
# Sun sign_num                 0
# Sun position                 0
# Sun abs_pos                  0
# Sun point_type               0
# Sun house                    0
# Sun retrograde               0
# Moon quality                 0
# Moon element                 0
# Moon sign                    0
# Moon sign_num                0
# Moon position                0
# Moon abs_pos                 0
# Moon point_type              0
# Moon house                   0
# Moon retrograde              0
# Mercury quality              0
# Mercury element              0
# Mercury sign                 0
# Mercury sign_num             0
# Mercury position             0
# Mercury abs_pos              0
# Mercury point_type           0
# Mercury house                0
# Mercury retrograde           0
# Venus quality                0
# Venus element                0
# Venus sign                   0
# True_Node position          7.542601    15.113912    22.602029    29.999996
# True_Node abs_pos         107.217163   208.376988   281.424223   359.974930
# True_Node retrograde        0.000000     1.000000     1.000000     1.000000
# First House sign_num        3.000000     6.000000     8.000000    11.000000
# First House position        7.509809    14.990868    22.523338    29.999711
# First House abs_pos       112.993312   180.729048   248.138414   359.998124
# Second House sign_num       3.000000     6.000000     8.000000    11.000000
# Second House position       7.517519    15.054166    22.519711    29.999910
# Second House abs_pos      105.438357   180.155701   254.643803   359.994259
# Third House sign_num        3.000000     6.000000     8.000000    11.000000
# Third House position        7.498581    15.027953    22.459307    29.999439
# Third House abs_pos        97.970270   180.510956   262.364280   359.995019
# Fourth House sign_num       2.000000     6.000000     9.000000    11.000000
# Fourth House position       7.453400    14.959136    22.476935    29.999700
# Fourth House abs_pos       89.261367   180.019296   270.146203   359.998364
# Fifth House sign_num        2.000000     5.000000     9.000000    11.000000
# Fifth House position        7.500367    14.981392    22.491568    29.999383
# Fifth House abs_pos        81.656435   179.224368   277.948837   359.995376
# Sixth House sign_num        2.000000     5.000000     9.000000    11.000000
# Sixth House position        7.519147    15.033929    22.498664    29.999688
# Sixth House abs_pos        73.934123   178.947909   285.671657   359.999094
# Seventh House sign_num      2.000000     5.000000     9.000000    11.000000
# Seventh House position      7.509809    14.990868    22.523338    29.999711
# Seventh House abs_pos      67.460851   178.094691   292.315368   359.998057
# Eighth House sign_num       2.000000     5.000000     9.000000    11.000000
# Eighth House position       7.517519    15.054166    22.519711    29.999910
# Eighth House abs_pos       74.489056   179.773721   285.274784   359.999431
# Ninth House sign_num        2.000000     5.000000     9.000000    11.000000
# Ninth House position        7.498581    15.027953    22.459307    29.999439
# Ninth House abs_pos        81.905717   179.361139   277.460559   359.996176
# Tenth House sign_num        3.000000     5.000000     8.000000    11.000000
# Tenth House position        7.453400    14.959136    22.476935    29.999700
# Tenth House abs_pos        90.139271   179.995431   269.241798   359.998891
# Eleventh House sign_num     3.000000     6.000000     8.000000    11.000000
# Eleventh House position     7.500367    14.981392    22.491568    29.999383
# Eleventh House abs_pos     98.448676   180.524738   262.120909   359.995833
# Twelfth House sign_num      3.000000     6.000000     8.000000    11.000000
# Twelfth House position      7.519147    15.033929    22.498664    29.999688
# Twelfth House abs_pos     106.216992   180.519985   254.449129   359.995731

# %%
df_eq = df[df["BigEarthquake"]==1]
df_eq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5304 entries, 115214 to 120517
# Columns: 201 entries, Latitude to Twelfth House point_type
# dtypes: float64(51), int64(42), object(108)
# memory usage: 8.2+ MB

# %%
pd.crosstab(df_eq.Year, df_eq.BigEarthquake).plot(kind="bar", figsize=(10,6))
# Out:
# <Axes: xlabel='Year'>

# %%
df_eq.Magnitude.plot.hist();

# %%
pd.options.display.max_rows = 4000
df_eq.corr()
# Out:
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_82818/2111517492.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   
# Eleventh House sign_num  0.033786   0.002063   0.010168  0.002714 -0.001419
# Eleventh House position  0.013363  -0.005791   0.005019 -0.001381 -0.015383
# Eleventh House abs_pos   0.034892   0.001553   0.010588  0.002588 -0.002762
# Twelfth House sign_num   0.032854  -0.005957   0.009100  0.007776 -0.019264
# Twelfth House position  -0.013468  -0.005093  -0.007641 -0.006324 -0.020297
# Twelfth House abs_pos    0.031530  -0.006422   0.008367  0.007169 -0.021123
#
#                               Day      Hour    Minute  BigEarthquake  \
# Latitude                -0.006071 -0.001805  0.006500            NaN
# Longitude               -0.001776  0.009836 -0.000069            NaN
# Magnitude                0.003612  0.000799 -0.009211            NaN
# Year                    -0.037095  0.001396 -0.002124            NaN
# Month                    0.034640 -0.007737  0.012246            NaN
# Day                      1.000000  0.008976 -0.018514            NaN
# Hour                     0.008976  1.000000 -0.015695            NaN
# Minute                  -0.018514 -0.015695  1.000000            NaN
# BigEarthquake                 NaN       NaN       NaN            NaN
# Sun sign_num            -0.019514 -0.003952  0.012012            NaN
# Sun position            -0.309937 -0.017366 -0.013318            NaN
# Sun abs_pos             -0.045258 -0.005382  0.010851            NaN
# Sun retrograde                NaN       NaN       NaN            NaN
# Moon sign_num           -0.001142  0.010635  0.010952            NaN
# Moon position           -0.012523  0.024500  0.003569            NaN
# Moon abs_pos            -0.002187  0.012639  0.011200            NaN
# Moon retrograde               NaN       NaN       NaN            NaN
# Mercury sign_num        -0.028667  0.004541  0.016397            NaN
# Mercury position         0.080749  0.015336 -0.006571            NaN
# Mercury abs_pos         -0.021755  0.005795  0.015753            NaN
# Mercury retrograde      -0.014507  0.007914 -0.010252            NaN
# Venus sign_num           0.000521 -0.010861  0.003450            NaN
# Venus position           0.023282  0.016099 -0.012400            NaN
# Venus abs_pos            0.002443 -0.009509  0.002419            NaN
# Venus retrograde        -0.007853  0.005427 -0.018211            NaN
# Mars sign_num           -0.003561  0.006954 -0.013160            NaN
# Mars position           -0.022078 -0.005142  0.024690            NaN
# Mars abs_pos            -0.005515  0.006504 -0.010986            NaN
# Mars retrograde          0.009163 -0.009810 -0.011553            NaN
# Jupiter sign_num         0.012673  0.008344  0.000793            NaN
# Jupiter position        -0.007696  0.010855  0.005620            NaN
# Jupiter abs_pos          0.011968  0.009089  0.001212            NaN
# Jupiter retrograde      -0.014854 -0.019935  0.021065            NaN
# Saturn sign_num         -0.008532 -0.011136 -0.013133            NaN
# Saturn position         -0.002655 -0.006413  0.002023            NaN
# Saturn abs_pos          -0.008761 -0.011708 -0.012916            NaN
# Saturn retrograde       -0.024405 -0.020515  0.009356            NaN
# Uranus sign_num         -0.007577  0.012606 -0.005702            NaN
# Uranus position         -0.018252 -0.010336  0.009576            NaN
# Uranus abs_pos          -0.009062  0.011272 -0.004640            NaN
# Uranus retrograde        0.022053 -0.010542  0.002864            NaN
# Neptune sign_num        -0.030648 -0.002414 -0.002524            NaN
# Neptune position        -0.014918  0.011458  0.001128            NaN
# Neptune abs_pos         -0.035315  0.001314 -0.002145            NaN
# Neptune retrograde       0.021105 -0.000525  0.006293            NaN
# Pluto sign_num          -0.041078  0.001345  0.005729            NaN
# Pluto position           0.029102  0.001370 -0.028955            NaN
# Pluto abs_pos           -0.035130  0.001828 -0.002361            NaN
# Pluto retrograde        -0.013397 -0.001134  0.000317            NaN
# Mean_Node sign_num      -0.011587  0.001049 -0.008544            NaN
# Mean_Node position      -0.030270  0.029888 -0.013192            NaN
# Mean_Node abs_pos       -0.014131  0.003577 -0.009648            NaN
# Mean_Node retrograde          NaN       NaN       NaN            NaN
# True_Node sign_num      -0.016863  0.002557 -0.010528            NaN
# True_Node position      -0.032065  0.032538 -0.015124            NaN
# True_Node abs_pos       -0.019557  0.005306 -0.011797            NaN
# True_Node retrograde     0.004441 -0.002906  0.003515            NaN
# First House sign_num    -0.008312  0.011355  0.038197            NaN
# First House position    -0.014816  0.022939 -0.024740            NaN
# First House abs_pos     -0.009762  0.013600  0.035785            NaN
# Second House sign_num   -0.005405  0.041263  0.035142            NaN
# Second House position   -0.007910 -0.024781 -0.004806            NaN
# Second House abs_pos    -0.006132  0.038900  0.034643            NaN
# Third House sign_num     0.011730  0.041343  0.033349            NaN
# Third House position    -0.002327  0.000009 -0.019515            NaN
# Third House abs_pos      0.011498  0.041245  0.031560            NaN
# Fourth House sign_num    0.018837  0.050506  0.013829            NaN
# Fourth House position   -0.027232  0.017450 -0.021736            NaN
# Fourth House abs_pos     0.016534  0.051934  0.011991            NaN
# Fifth House sign_num     0.019694  0.031675 -0.001719            NaN
# Fifth House position     0.010228  0.035859 -0.020825            NaN
# Fifth House abs_pos      0.020434  0.034422 -0.003382            NaN
# Sixth House sign_num     0.018642 -0.002823 -0.024340            NaN
# Sixth House position     0.020842  0.010677 -0.001669            NaN
# Sixth House abs_pos      0.020204 -0.001976 -0.024378            NaN
# Seventh House sign_num  -0.003717 -0.027401 -0.017383            NaN
# Seventh House position  -0.014816  0.022939 -0.024740            NaN
# Seventh House abs_pos   -0.004816 -0.025586 -0.019179            NaN
# Eighth House sign_num   -0.024741 -0.040636 -0.030438            NaN
# Eighth House position   -0.007910 -0.024781 -0.004806            NaN
# Eighth House abs_pos    -0.025257 -0.042416 -0.030685            NaN
# Ninth House sign_num    -0.023804 -0.044158 -0.031092            NaN
# Ninth House position    -0.002327  0.000009 -0.019515            NaN
# Ninth House abs_pos     -0.023955 -0.044086 -0.032627            NaN
# Tenth House sign_num    -0.022364 -0.027733 -0.019558            NaN
# Tenth House position    -0.027232  0.017450 -0.021736            NaN
# Tenth House abs_pos     -0.024583 -0.026159 -0.021323            NaN
# Eleventh House sign_num -0.004258 -0.033905  0.002334            NaN
# Eleventh House position  0.010228  0.035859 -0.020825            NaN
# Eleventh House abs_pos  -0.003356 -0.030705  0.000508            NaN
# Twelfth House sign_num  -0.007077 -0.007589  0.002306            NaN
# Twelfth House position   0.020842  0.010677 -0.001669            NaN
# Twelfth House abs_pos   -0.005114 -0.006575  0.002145            NaN
#
#                          Sun sign_num  ...  Ninth House abs_pos  \
# Latitude                    -0.024186  ...             0.022200
# Longitude                    0.018180  ...            -0.001511
# Magnitude                   -0.007161  ...             0.007387
# Year                         0.029407  ...             0.016962
# Month                       -0.028101  ...            -0.003861
# Day                         -0.019514  ...            -0.023955
# Hour                        -0.003952  ...            -0.044086
# Minute                       0.012012  ...            -0.032627
# BigEarthquake                     NaN  ...                  NaN
# Sun sign_num                 1.000000  ...             0.002048
# Sun position                 0.008939  ...            -0.001555
# Sun abs_pos                  0.996522  ...             0.001909
# Sun retrograde                    NaN  ...                  NaN
# Moon sign_num               -0.018107  ...             0.010540
# Moon position               -0.009320  ...            -0.005716
# Moon abs_pos                -0.018804  ...             0.010012
# Moon retrograde                   NaN  ...                  NaN
# Mercury sign_num             0.735977  ...            -0.003805
# Mercury position            -0.004879  ...            -0.010900
# Mercury abs_pos              0.731285  ...            -0.004694
# Mercury retrograde          -0.005125  ...             0.001399
# Venus sign_num               0.617554  ...             0.003052
# Venus position               0.003162  ...             0.012053
# Venus abs_pos                0.616523  ...             0.004041
# Venus retrograde            -0.038939  ...            -0.024937
# Mars sign_num                0.247642  ...             0.015199
# Mars position               -0.070694  ...             0.009046
# Mars abs_pos                 0.241552  ...             0.016008
# Mars retrograde              0.070914  ...             0.014304
# Jupiter sign_num             0.024472  ...            -0.028867
# Jupiter position            -0.018253  ...            -0.026155
# Jupiter abs_pos              0.022854  ...            -0.030579
# Jupiter retrograde          -0.071569  ...            -0.039193
# Saturn sign_num              0.041306  ...             0.011322
# Saturn position              0.006591  ...            -0.006881
# Saturn abs_pos               0.041828  ...             0.010656
# Saturn retrograde            0.134945  ...             0.008645
# Uranus sign_num              0.072638  ...            -0.020921
# Uranus position              0.067788  ...            -0.026639
# Uranus abs_pos               0.076852  ...            -0.022799
# Uranus retrograde           -0.360217  ...            -0.004182
# Neptune sign_num             0.008706  ...             0.017462
# Neptune position             0.021072  ...            -0.001921
# Neptune abs_pos              0.015490  ...             0.016742
# Neptune retrograde          -0.531492  ...             0.005157
# Pluto sign_num               0.048721  ...             0.008954
# Pluto position              -0.027644  ...             0.022178
# Pluto abs_pos                0.043672  ...             0.015976
# Pluto retrograde            -0.570088  ...            -0.012014
# Mean_Node sign_num          -0.005855  ...             0.029140
# Mean_Node position           0.058562  ...             0.032016
# Mean_Node abs_pos           -0.000890  ...             0.031806
# Mean_Node retrograde              NaN  ...                  NaN
# True_Node sign_num          -0.008378  ...             0.028363
# True_Node position           0.054234  ...             0.052219
# True_Node abs_pos           -0.003784  ...             0.032750
# True_Node retrograde         0.022911  ...             0.023287
# First House sign_num        -0.001295  ...            -0.310748
# First House position         0.023302  ...            -0.029740
# First House abs_pos          0.000983  ...            -0.313707
# Second House sign_num       -0.024250  ...            -0.458437
# Second House position       -0.022510  ...             0.022923
# Second House abs_pos        -0.026304  ...            -0.455617
# Third House sign_num         0.001759  ...            -0.525525
# Third House position        -0.009483  ...             0.060484
# Third House abs_pos          0.000924  ...            -0.518969
# Fourth House sign_num       -0.005496  ...            -0.477193
# Fourth House position        0.007216  ...             0.029810
# Fourth House abs_pos        -0.004885  ...            -0.474323
# Fifth House sign_num        -0.005383  ...            -0.321301
# Fifth House position         0.005674  ...             0.000200
# Fifth House abs_pos         -0.004906  ...            -0.319986
# Sixth House sign_num         0.008303  ...            -0.073063
# Sixth House position         0.014141  ...            -0.054572
# Sixth House abs_pos          0.009380  ...            -0.077061
# Seventh House sign_num       0.003165  ...             0.262113
# Seventh House position       0.023302  ...            -0.029740
# Seventh House abs_pos        0.004902  ...             0.258986
# Eighth House sign_num        0.004134  ...             0.614767
# Eighth House position       -0.022510  ...             0.022923
# Eighth House abs_pos         0.002338  ...             0.613892
# Ninth House sign_num         0.002823  ...             0.996696
# Ninth House position        -0.009483  ...             0.060484
# Ninth House abs_pos          0.002048  ...             1.000000
# Tenth House sign_num         0.014690  ...             0.518491
# Tenth House position         0.007216  ...             0.029810
# Tenth House abs_pos          0.015246  ...             0.519137
# Eleventh House sign_num      0.011047  ...             0.140706
# Eleventh House position      0.005674  ...             0.000200
# Eleventh House abs_pos       0.011522  ...             0.140460
# Twelfth House sign_num       0.005445  ...            -0.126782
# Twelfth House position       0.014141  ...            -0.054572
# Twelfth House abs_pos        0.006756  ...            -0.131633
#
#                          Tenth House sign_num  Tenth House position  \
# Latitude                             0.033824              0.017217
# Longitude                            0.005580             -0.012926
# Magnitude                            0.021863              0.002945
# Year                                 0.013302             -0.023066
# Month                                0.006313              0.000994
# Day                                 -0.022364             -0.027232
# Hour                                -0.027733              0.017450
# Minute                              -0.019558             -0.021736
# BigEarthquake                             NaN                   NaN
# Sun sign_num                         0.014690              0.007216
# Sun position                        -0.013678              0.011160
# Sun abs_pos                          0.013488              0.008116
# Sun retrograde                            NaN                   NaN
# Moon sign_num                        0.009444              0.020988
# Moon position                       -0.019039              0.010028
# Moon abs_pos                         0.007805              0.021731
# Moon retrograde                           NaN                   NaN
# Mercury sign_num                     0.004898             -0.002012
# Mercury position                     0.005023             -0.021965
# Mercury abs_pos                      0.005290             -0.003835
# Mercury retrograde                  -0.017747              0.018310
# Venus sign_num                      -0.001819              0.007022
# Venus position                       0.002475             -0.007682
# Venus abs_pos                       -0.001611              0.006373
# Venus retrograde                    -0.018157              0.001251
# Mars sign_num                       -0.000906              0.004931
# Mars position                        0.025909              0.014118
# Mars abs_pos                         0.001384              0.006183
# Mars retrograde                      0.007413              0.009629
# Jupiter sign_num                    -0.020832             -0.016483
# Jupiter position                    -0.012343             -0.003967
# Jupiter abs_pos                     -0.021572             -0.016628
# Jupiter retrograde                  -0.022424             -0.017885
# Saturn sign_num                      0.001080             -0.011780
# Saturn position                     -0.013440              0.020117
# Saturn abs_pos                      -0.000173             -0.009881
# Saturn retrograde                    0.007477              0.008042
# Uranus sign_num                     -0.010471              0.017207
# Uranus position                      0.004966              0.005704
# Uranus abs_pos                      -0.009701              0.017238
# Uranus retrograde                   -0.009026              0.006161
# Neptune sign_num                     0.016327             -0.029398
# Neptune position                    -0.009073              0.018251
# Neptune abs_pos                      0.013294             -0.023317
# Neptune retrograde                   0.001781              0.001335
# Pluto sign_num                       0.010034             -0.021305
# Pluto position                       0.008310             -0.000965
# Pluto abs_pos                        0.013079             -0.022905
# Pluto retrograde                    -0.003833             -0.004863
# Mean_Node sign_num                   0.006672              0.004209
# Mean_Node position                   0.010976             -0.005067
# Mean_Node abs_pos                    0.007591              0.003774
# Mean_Node retrograde                      NaN                   NaN
# True_Node sign_num                   0.004932              0.002419
# True_Node position                   0.023878             -0.003727
# True_Node abs_pos                    0.006946              0.002102
# True_Node retrograde                 0.016478             -0.019814
# First House sign_num                -0.108871              0.111548
# First House position                -0.024518              0.191422
# First House abs_pos                 -0.111286              0.130281
# Second House sign_num               -0.310859              0.084830
# Second House position               -0.014715             -0.125957
# Second House abs_pos                -0.311756              0.073007
# Third House sign_num                -0.453684              0.036206
# Third House position                 0.015547              0.105322
# Third House abs_pos                 -0.451235              0.045342
# Fourth House sign_num               -0.521961             -0.032976
# Fourth House position                0.000438              1.000000
# Fourth House abs_pos                -0.521526              0.051104
# Fifth House sign_num                -0.491487              0.013953
# Fifth House position                 0.004071              0.158122
# Fifth House abs_pos                 -0.489173              0.026574
# Sixth House sign_num                -0.349823              0.040716
# Sixth House position                -0.029492             -0.127910
# Sixth House abs_pos                 -0.350798              0.030536
# Seventh House sign_num              -0.097018              0.056817
# Seventh House position              -0.024518              0.191422
# Seventh House abs_pos               -0.098525              0.070983
# Eighth House sign_num                0.199840              0.039892
# Eighth House position               -0.014715             -0.125957
# Eighth House abs_pos                 0.197805              0.029770
# Ninth House sign_num                 0.518065              0.021287
# Ninth House position                 0.015547              0.105322
# Ninth House abs_pos                  0.518491              0.029810
# Tenth House sign_num                 1.000000              0.000438
# Tenth House position                 0.000438              1.000000
# Tenth House abs_pos                  0.996427              0.084893
# Eleventh House sign_num              0.516374              0.065837
# Eleventh House position              0.004071              0.158122
# Eleventh House abs_pos               0.515764              0.079544
# Twelfth House sign_num               0.153525              0.086562
# Twelfth House position              -0.029492             -0.127910
# Twelfth House abs_pos                0.150463              0.074429
#
#                          Tenth House abs_pos  Eleventh House sign_num  \
# Latitude                            0.035156                 0.033786
# Longitude                           0.004468                 0.002063
# Magnitude                           0.022033                 0.010168
# Year                                0.011306                 0.002714
# Month                               0.006374                -0.001419
# Day                                -0.024583                -0.004258
# Hour                               -0.026159                -0.033905
# Minute                             -0.021323                 0.002334
# BigEarthquake                            NaN                      NaN
# Sun sign_num                        0.015246                 0.011047
# Sun position                       -0.012686                -0.018731
# Sun abs_pos                         0.014125                 0.009439
# Sun retrograde                           NaN                      NaN
# Moon sign_num                       0.011183                -0.011016
# Moon position                      -0.018123                -0.016532
# Moon abs_pos                        0.009612                -0.012350
# Moon retrograde                          NaN                      NaN
# Mercury sign_num                    0.004711                -0.017384
# Mercury position                    0.003150                -0.014493
# Mercury abs_pos                     0.004947                -0.018494
# Mercury retrograde                 -0.016137                -0.017686
# Venus sign_num                     -0.001219                 0.006107
# Venus position                      0.001818                -0.004953
# Venus abs_pos                      -0.001067                 0.005685
# Venus retrograde                   -0.017986                 0.000789
# Mars sign_num                      -0.000486                -0.023085
# Mars position                       0.027007                 0.025435
# Mars abs_pos                        0.001901                -0.020851
# Mars retrograde                     0.008199                 0.025086
# Jupiter sign_num                   -0.022149                -0.009981
# Jupiter position                   -0.012633                 0.019565
# Jupiter abs_pos                    -0.022898                -0.008400
# Jupiter retrograde                 -0.023854                 0.001371
# Saturn sign_num                     0.000081                 0.005422
# Saturn position                    -0.011692                -0.009921
# Saturn abs_pos                     -0.001007                 0.004486
# Saturn retrograde                   0.008129                 0.022912
# Uranus sign_num                    -0.008980                 0.005141
# Uranus position                     0.005430                 0.010777
# Uranus abs_pos                     -0.008210                 0.005998
# Uranus retrograde                  -0.008473                 0.007607
# Neptune sign_num                    0.013785                 0.004106
# Neptune position                   -0.007499                -0.005714
# Neptune abs_pos                     0.011277                 0.002230
# Neptune retrograde                  0.001888                 0.011366
# Pluto sign_num                      0.008199                -0.003220
# Pluto position                      0.008199                 0.017606
# Pluto abs_pos                       0.011097                 0.001716
# Pluto retrograde                   -0.004230                -0.001545
# Mean_Node sign_num                  0.007003                 0.011826
# Mean_Node position                  0.010508                 0.001999
# Mean_Node abs_pos                   0.007882                 0.011978
# Mean_Node retrograde                     NaN                      NaN
# True_Node sign_num                  0.005119                 0.010479
# True_Node position                  0.023477                 0.011614
# True_Node abs_pos                   0.007098                 0.011451
# True_Node retrograde                0.014746                -0.005485
# First House sign_num               -0.099057                 0.155822
# First House position               -0.008263                 0.061701
# First House abs_pos                -0.099881                 0.161880
# Second House sign_num              -0.302573                -0.105680
# Second House position              -0.025300                -0.029308
# Second House abs_pos               -0.304465                -0.108242
# Third House sign_num               -0.448989                -0.309853
# Third House position                0.024386                 0.003649
# Third House abs_pos                -0.445777                -0.308790
# Fourth House sign_num              -0.522862                -0.466940
# Fourth House position               0.084893                 0.065837
# Fourth House abs_pos               -0.515327                -0.461050
# Fifth House sign_num               -0.488534                -0.534612
# Fifth House position                0.017411                -0.022401
# Fifth House abs_pos                -0.485163                -0.534246
# Sixth House sign_num               -0.345122                -0.503523
# Sixth House position               -0.040188                -0.039811
# Sixth House abs_pos                -0.346953                -0.504720
# Seventh House sign_num             -0.091869                -0.351321
# Seventh House position             -0.008263                 0.061701
# Seventh House abs_pos              -0.092175                -0.345492
# Eighth House sign_num               0.202488                -0.110434
# Eighth House position              -0.025300                -0.029308
# Eighth House abs_pos                0.199606                -0.112266
# Ninth House sign_num                0.517992                 0.140636
# Ninth House position                0.024386                 0.003649
# Ninth House abs_pos                 0.519137                 0.140706
# Tenth House sign_num                0.996427                 0.516374
# Tenth House position                0.084893                 0.065837
# Tenth House abs_pos                 1.000000                 0.520070
# Eleventh House sign_num             0.520070                 1.000000
# Eleventh House position             0.017411                -0.022401
# Eleventh House abs_pos              0.520620                 0.996169
# Twelfth House sign_num              0.160282                 0.518758
# Twelfth House position             -0.040188                -0.039811
# Twelfth House abs_pos               0.156205                 0.514005
#
#                          Eleventh House position  Eleventh House abs_pos  \
# Latitude                                0.013363                0.034892
# Longitude                              -0.005791                0.001553
# Magnitude                               0.005019                0.010588
# Year                                   -0.001381                0.002588
# Month                                  -0.015383               -0.002762
# Eighth House sign_num                   0.000982               -0.110141
# Eighth House position                  -0.177402               -0.044770
# Eighth House abs_pos                   -0.013033               -0.113196
# Ninth House sign_num                    0.015279                0.141710
# Ninth House position                   -0.185290               -0.012564
# Ninth House abs_pos                     0.000200                0.140460
# Tenth House sign_num                    0.004071                0.515764
# Tenth House position                    0.158122                0.079544
# Tenth House abs_pos                     0.017411                0.520620
# Eleventh House sign_num                -0.022401                0.996169
# Eleventh House position                 1.000000                0.065108
# Eleventh House abs_pos                  0.065108                1.000000
# Twelfth House sign_num                 -0.033282                0.514876
# Twelfth House position                  0.069984               -0.033615
# Twelfth House abs_pos                  -0.026672                0.510711
#
#                          Twelfth House sign_num  Twelfth House position  \
# Latitude                               0.032854               -0.013468
# Longitude                             -0.005957               -0.005093
# Magnitude                              0.009100               -0.007641
# Year                                   0.007776               -0.006324
# Month                                 -0.019264               -0.020297
# Day                                   -0.007077                0.020842
# Hour                                  -0.007589                0.010677
# Minute                                 0.002306               -0.001669
# BigEarthquake                               NaN                     NaN
# Sun sign_num                           0.005445                0.014141
# Sun position                           0.006966               -0.004193
# Sun abs_pos                            0.006002                0.013731
# Sun retrograde                              NaN                     NaN
# Moon sign_num                         -0.015485               -0.011827
# Moon position                         -0.022447                0.013762
# Moon abs_pos                          -0.017295               -0.010619
# Moon retrograde                             NaN                     NaN
# Mercury sign_num                      -0.024380                0.019452
# Mercury position                      -0.020268               -0.001874
# Mercury abs_pos                       -0.025931                0.019183
# Mercury retrograde                    -0.017637               -0.003155
# Venus sign_num                        -0.002493               -0.009172
# Venus position                         0.014540                0.002185
# Venus abs_pos                         -0.001287               -0.008972
# Venus retrograde                       0.001596               -0.008184
# Mars sign_num                         -0.015440               -0.001003
# Mars position                          0.022309                0.002000
# Mars abs_pos                          -0.013478               -0.000827
# Mars retrograde                        0.009867               -0.008362
# Jupiter sign_num                      -0.015076               -0.025233
# Jupiter position                       0.008188               -0.018578
# Jupiter abs_pos                       -0.014311               -0.026405
# Jupiter retrograde                     0.000306                0.000710
# Saturn sign_num                       -0.009804               -0.002363
# Saturn position                       -0.011252                0.015334
# Saturn abs_pos                        -0.010830               -0.000930
# Saturn retrograde                      0.022199               -0.008654
# Uranus sign_num                        0.021198               -0.014252
# Uranus position                        0.014034               -0.004092
# Uranus abs_pos                         0.021890               -0.014218
# Uranus retrograde                      0.000634                0.011672
# Neptune sign_num                       0.003116                0.000532
# Neptune position                       0.015307               -0.020467
# Neptune abs_pos                        0.008062               -0.006107
# Neptune retrograde                    -0.005835                0.008188
# Pluto sign_num                         0.009835               -0.007380
# Pluto position                        -0.009272                0.003585
# Pluto abs_pos                          0.007739               -0.006791
# Pluto retrograde                       0.019876               -0.003210
# Mean_Node sign_num                    -0.007697               -0.021878
# Mean_Node position                    -0.003568               -0.014605
# Mean_Node abs_pos                     -0.007988               -0.023082
# Mean_Node retrograde                        NaN                     NaN
# True_Node sign_num                    -0.008043               -0.021728
# True_Node position                     0.003784               -0.018686
# True_Node abs_pos                     -0.007715               -0.023286
# True_Node retrograde                   0.011932               -0.004119
# First House sign_num                   0.489879               -0.039851
# First House position                  -0.004615                0.000069
# First House abs_pos                    0.489510               -0.039851
# Second House sign_num                  0.136108               -0.030758
# Second House position                 -0.038419               -0.130418
# Second House abs_pos                   0.132336               -0.042821
# Third House sign_num                  -0.118543               -0.030337
# Third House position                  -0.010713               -0.151306
# Third House abs_pos                   -0.119197               -0.043514
# Fourth House sign_num                 -0.332521               -0.019819
# Fourth House position                  0.086562               -0.127910
# Fourth House abs_pos                  -0.324991               -0.030556
# Fifth House sign_num                  -0.470295                0.023849
# Fifth House position                  -0.033282                0.069984
# Fifth House abs_pos                   -0.471062                0.029363
# Sixth House sign_num                  -0.546958                0.009491
# Sixth House position                  -0.025595                1.000000
# Sixth House abs_pos                   -0.546875                0.087827
# Seventh House sign_num                -0.499147                0.014911
# Seventh House position                -0.004615                0.000069
# Seventh House abs_pos                 -0.497788                0.014865
# Eighth House sign_num                 -0.322231               -0.041675
# Eighth House position                 -0.038419               -0.130418
# Eighth House abs_pos                  -0.323857               -0.051793
# Ninth House sign_num                  -0.126115               -0.042347
# Ninth House position                  -0.010713               -0.151306
# Ninth House abs_pos                   -0.126782               -0.054572
# Tenth House sign_num                   0.153525               -0.029492
# Tenth House position                   0.086562               -0.127910
# Tenth House abs_pos                    0.160282               -0.040188
# Eleventh House sign_num                0.518758               -0.039811
# Eleventh House position               -0.033282                0.069984
# Eleventh House abs_pos                 0.514876               -0.033615
# Twelfth House sign_num                 1.000000               -0.025595
# Twelfth House position                -0.025595                1.000000
# Twelfth House abs_pos                  0.995621                0.067965
#
#                          Twelfth House abs_pos
# Latitude                              0.031530
# Longitude                            -0.006422
# Magnitude                             0.008367
# Year                                  0.007169
# Month                                -0.021123
# Day                                  -0.005114
# Hour                                 -0.006575
# Minute                                0.002145
# BigEarthquake                              NaN
# Sun sign_num                          0.006756
# Sun position                          0.006560
# Sun abs_pos                           0.007274
# Sun retrograde                             NaN
# Moon sign_num                        -0.016561
# Moon position                        -0.021115
# Moon abs_pos                         -0.018253
# Moon retrograde                            NaN
# Mercury sign_num                     -0.022513
# Mercury position                     -0.020403
# Mercury abs_pos                      -0.024086
# Mercury retrograde                   -0.017897
# Venus sign_num                       -0.003346
# Venus position                        0.014715
# Venus abs_pos                        -0.002123
# Venus retrograde                      0.000828
# Mars sign_num                        -0.015503
# Mars position                         0.022451
# Mars abs_pos                         -0.013529
# Mars retrograde                       0.009065
# Jupiter sign_num                     -0.017406
# Jupiter position                      0.006435
# Jupiter abs_pos                      -0.016752
# Jupiter retrograde                    0.000371
# Saturn sign_num                      -0.010005
# Saturn position                      -0.009796
# Saturn abs_pos                       -0.010895
# Saturn retrograde                     0.021346
# Uranus sign_num                       0.019823
# Uranus position                       0.013623
# Uranus abs_pos                        0.020517
# Uranus retrograde                     0.001724
# Neptune sign_num                      0.003160
# Neptune position                      0.013363
# Neptune abs_pos                       0.007475
# Neptune retrograde                   -0.005058
# Pluto sign_num                        0.009125
# Pluto position                       -0.008918
# Pluto abs_pos                         0.007089
# Pluto retrograde                      0.019536
# Mean_Node sign_num                   -0.009728
# Mean_Node position                   -0.004927
# Mean_Node abs_pos                    -0.010130
# Mean_Node retrograde                       NaN
# True_Node sign_num                   -0.010059
# True_Node position                    0.002029
# True_Node abs_pos                    -0.009877
# True_Node retrograde                  0.011523
# First House sign_num                  0.485180
# First House position                 -0.004600
# First House abs_pos                   0.484812
# Second House sign_num                 0.132962
# Second House position                -0.050538
# Second House abs_pos                  0.128069
# Third House sign_num                 -0.121145
# Third House position                 -0.024840
# Third House abs_pos                  -0.123030
# Fourth House sign_num                -0.333714
# Fourth House position                 0.074429
# Fourth House abs_pos                 -0.327203
# Fifth House sign_num                 -0.467132
# Fifth House position                 -0.026672
# Fifth House abs_pos                  -0.467381
# Sixth House sign_num                 -0.544985
# Sixth House position                  0.067965
# Sixth House abs_pos                  -0.537576
# Seventh House sign_num               -0.496762
# Seventh House position               -0.004600
# Seventh House abs_pos                -0.495410
# Eighth House sign_num                -0.325488
# Eighth House position                -0.050538
# Eighth House abs_pos                 -0.328057
# Ninth House sign_num                 -0.129825
# Ninth House position                 -0.024840
# Ninth House abs_pos                  -0.131633
# Tenth House sign_num                  0.150463
# Tenth House position                  0.074429
# Tenth House abs_pos                   0.156205
# Eleventh House sign_num               0.514005
# Eleventh House position              -0.026672
# Eleventh House abs_pos                0.510711
# Twelfth House sign_num                0.995621
# Twelfth House position                0.067965
# Twelfth House abs_pos                 1.000000
#
# [93 rows x 93 columns]

# %% [markdown]
# No single feature seems to be correlated to magnitude, latitude or longitude.

# %%
df.corr()
# Out:
# /var/folders/dj/5n2bjn9d4ll_s915t85z__jw0000gn/T/ipykernel_82818/1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                          Latitude  Longitude  Magnitude      Year     Month  \
# Latitude                 1.000000  -0.000042  -0.031602 -0.001501  0.000634
# Longitude               -0.000042   1.000000   0.087832  0.005018 -0.002856
# Magnitude               -0.031602   0.087832   1.000000  0.051411  0.005221
# Year                    -0.001501   0.005018   0.051411  1.000000 -0.003763
# Month                    0.000634  -0.002856   0.005221 -0.003763  1.000000
# Day                     -0.000579   0.002611  -0.002123  0.004403  0.009570
# Hour                    -0.005114  -0.000788   0.001275  0.002653 -0.002425
# Minute                   0.000449   0.001369  -0.002684 -0.003890  0.001362
# BigEarthquake           -0.032024   0.087426   0.997744  0.051300  0.005029
# Sun sign_num            -0.002522   0.000081   0.001094  0.003203 -0.037282
# Sun position             0.002207   0.001407   0.003736 -0.001356 -0.008172
# Sun abs_pos             -0.002331   0.000198   0.001401  0.003080 -0.037836
# Sun retrograde                NaN        NaN        NaN       NaN       NaN
# Moon sign_num           -0.003337   0.001361  -0.000935 -0.003952  0.000689
# Moon position            0.001880   0.001324  -0.002043  0.006380  0.002971
# Moon abs_pos            -0.003170   0.001467  -0.001103 -0.003406  0.000935
# Moon retrograde               NaN        NaN        NaN       NaN       NaN
# Mercury sign_num        -0.002278  -0.002813  -0.009400  0.012957 -0.062506
# Mercury position         0.003998  -0.001737   0.003832 -0.008446  0.004099
# Mercury abs_pos         -0.001936  -0.002952  -0.009052  0.012212 -0.061993
# Twelfth House sign_num       0.003900  ...            -0.105964
# Twelfth House position       0.000987  ...            -0.045014
# Twelfth House abs_pos        0.003989  ...            -0.110072
#
#                          Tenth House sign_num  Tenth House position  \
# Latitude                            -0.003148              0.003295
# Longitude                            0.002649             -0.003209
# Magnitude                            0.003024             -0.002027
# Year                                -0.001844              0.002433
# Month                                0.000063             -0.006616
# Day                                 -0.003289             -0.009720
# Hour                                -0.050260             -0.001874
# Minute                              -0.000149             -0.003791
# BigEarthquake                        0.002722             -0.002073
# Sun sign_num                         0.001076             -0.007555
# Sun position                        -0.002165              0.004710
# Sun abs_pos                          0.000892             -0.007138
# Sun retrograde                            NaN                   NaN
# Moon sign_num                       -0.000039             -0.001358
# Moon position                       -0.003917             -0.004688
# Moon abs_pos                        -0.000366             -0.001745
# Moon retrograde                           NaN                   NaN
# Mercury sign_num                     0.003506             -0.004411
# Mercury position                     0.000396             -0.003493
# Mercury abs_pos                      0.003530             -0.004693
# Mercury retrograde                  -0.001837              0.000254
# Venus sign_num                      -0.001037             -0.006657
# Venus position                      -0.001292              0.001649
# Venus abs_pos                       -0.001140             -0.006496
# Venus retrograde                     0.001607              0.000199
# Mars sign_num                       -0.001004             -0.007296
# Mars position                        0.000017             -0.002915
# Mars abs_pos                        -0.000999             -0.007525
# Mars retrograde                      0.004664             -0.004651
# Jupiter sign_num                     0.000573             -0.002369
# Jupiter position                    -0.002805             -0.000890
# Jupiter abs_pos                      0.000344             -0.002432
# Jupiter retrograde                   0.000153              0.001347
# Saturn sign_num                     -0.000087             -0.000944
# Saturn position                      0.003585              0.002524
# Saturn abs_pos                       0.000246             -0.000709
# Saturn retrograde                   -0.000304              0.001030
# Uranus sign_num                     -0.001348              0.000303
# Uranus position                      0.006050             -0.002984
# Uranus abs_pos                      -0.000747              0.000014
# Uranus retrograde                   -0.000018              0.005028
# Neptune sign_num                    -0.002408              0.001770
# Neptune position                     0.002466              0.002248
# Neptune abs_pos                     -0.001689              0.002521
# Neptune retrograde                  -0.002248              0.005653
# Pluto sign_num                      -0.000457              0.001499
# Pluto position                      -0.004542              0.001730
# Pluto abs_pos                       -0.001746              0.002067
# Pluto retrograde                     0.002690              0.008274
# Mean_Node sign_num                  -0.002005              0.003367
# Mean_Node position                   0.002526             -0.004495
# Mean_Node abs_pos                   -0.001785              0.002977
# Mean_Node retrograde                      NaN                   NaN
# True_Node sign_num                  -0.002596              0.003396
# True_Node position                   0.002827             -0.005613
# True_Node abs_pos                   -0.002352              0.002914
# True_Node retrograde                -0.003198              0.000271
# First House sign_num                -0.120668              0.091998
# First House position                -0.033331              0.208162
# First House abs_pos                 -0.123962              0.112497
# Second House sign_num               -0.319014              0.073698
# Second House position               -0.021440             -0.126859
# Second House abs_pos                -0.320626              0.061855
# Third House sign_num                -0.463234              0.040610
# Third House position                 0.050042              0.131455
# Third House abs_pos                 -0.457933              0.052074
# Fourth House sign_num               -0.528801             -0.001298
# Fourth House position               -0.011463              1.000000
# Fourth House abs_pos                -0.527963              0.082398
# Fifth House sign_num                -0.496108              0.034163
# Fifth House position                -0.018281              0.126474
# Fifth House abs_pos                 -0.495951              0.044187
# Sixth House sign_num                -0.348794              0.058762
# Sixth House position                -0.026332             -0.129337
# Sixth House abs_pos                 -0.349323              0.048536
# Seventh House sign_num              -0.097033              0.062017
# Seventh House position              -0.033331              0.208162
# Seventh House abs_pos               -0.099055              0.077201
# Eighth House sign_num                0.198278              0.051819
# Eighth House position               -0.021440             -0.126859
# Eighth House abs_pos                 0.195778              0.041802
# Ninth House sign_num                 0.548409              0.031035
# Ninth House position                 0.050042              0.131455
# Ninth House abs_pos                  0.550413              0.041489
# Tenth House sign_num                 1.000000             -0.011463
# Tenth House position                -0.011463              1.000000
# Tenth House abs_pos                  0.996458              0.072662
# Eleventh House sign_num              0.533117              0.039330
# Eleventh House position             -0.018281              0.126474
# Eleventh House abs_pos               0.530344              0.050396
# Twelfth House sign_num               0.153994              0.071451
# Twelfth House position              -0.026332             -0.129337
# Twelfth House abs_pos                0.151429              0.059367
#
#                          Tenth House abs_pos  Eleventh House sign_num  \
# Latitude                           -0.002863                -0.000780
# Longitude                           0.002372                 0.001244
# Magnitude                           0.002846                 0.000649
# Year                               -0.001635                -0.003510
# Month                              -0.000494                -0.002278
# Day                                -0.004098                -0.002679
# Hour                               -0.050288                -0.031378
# Minute                             -0.000467                 0.002085
# BigEarthquake                       0.002541                 0.000507
# Sun sign_num                        0.000438                 0.000620
# Sun position                       -0.001763                -0.002483
# Sun abs_pos                         0.000290                 0.000412
# Sun retrograde                           NaN                      NaN
# Moon sign_num                      -0.000153                 0.001143
# Moon position                      -0.004302                -0.001499
# Moon abs_pos                       -0.000512                 0.001014
# Moon retrograde                          NaN                      NaN
# Mercury sign_num                    0.003126                 0.000874
# Mercury position                    0.000101                 0.001058
# Mercury abs_pos                     0.003126                 0.000960
# Mercury retrograde                 -0.001811                -0.002061
# Venus sign_num                     -0.001594                -0.000645
# Venus position                     -0.001150                -0.000779
# Venus abs_pos                      -0.001684                -0.000708
# Venus retrograde                    0.001620                 0.006255
# Mars sign_num                      -0.001615                -0.005524
# Mars position                      -0.000228                 0.000636
# Mars abs_pos                       -0.001629                -0.005447
# Mars retrograde                     0.004261                 0.000623
# Jupiter sign_num                    0.000372                -0.000216
# Jupiter position                   -0.002872                -0.002807
# Jupiter abs_pos                     0.000139                -0.000442
# Jupiter retrograde                  0.000266                -0.001411
# Saturn sign_num                    -0.000167                 0.000918
# Saturn position                     0.003788                 0.001854
# Saturn abs_pos                      0.000185                 0.001090
# Saturn retrograde                  -0.000217                 0.002983
# Uranus sign_num                    -0.001319                -0.000049
# Uranus position                     0.005784                 0.007545
# Uranus abs_pos                     -0.000744                 0.000668
# Uranus retrograde                   0.000405                 0.002932
# Neptune sign_num                   -0.002253                -0.003835
# Neptune position                    0.002649                 0.002194
# Neptune abs_pos                    -0.001473                -0.003236
# Neptune retrograde                 -0.001767                -0.000286
# Pluto sign_num                     -0.000329                -0.003120
# Pluto position                     -0.004385                -0.000480
# Pluto abs_pos                      -0.001568                -0.003434
# Pluto retrograde                    0.003379                 0.005976
# Mean_Node sign_num                 -0.001716                -0.000551
# Mean_Node position                  0.002141                 0.001710
# Mean_Node abs_pos                  -0.001530                -0.000404
# Mean_Node retrograde                     NaN                      NaN
# True_Node sign_num                 -0.002304                -0.000525
# True_Node position                  0.002348                 0.003960
# True_Node abs_pos                  -0.002101                -0.000187
# True_Node retrograde               -0.003167                -0.005552
# First House sign_num               -0.112621                 0.129312
# First House position               -0.015739                 0.042747
# First House abs_pos                -0.114182                 0.133534
# Second House sign_num              -0.311994                -0.121455
# Second House position              -0.032053                -0.037735
# Second House abs_pos               -0.314598                -0.124809
# Third House sign_num               -0.458624                -0.322997
# Third House position                0.060968                 0.044042
# Third House abs_pos                -0.452373                -0.318498
# Fourth House sign_num              -0.527547                -0.466238
# Fourth House position               0.072662                 0.039330
# Fourth House abs_pos               -0.519672                -0.461361
# Fifth House sign_num               -0.491957                -0.531898
# Fifth House position               -0.007598                -0.019470
# Fifth House abs_pos                -0.490957                -0.531719
# Sixth House sign_num               -0.342954                -0.494742
# Sixth House position               -0.037140                -0.043390
# Sixth House abs_pos                -0.344341                -0.495957
# Seventh House sign_num             -0.091568                -0.339192
# Seventh House position             -0.015739                 0.042747
# Seventh House abs_pos              -0.092307                -0.334418
# Eighth House sign_num               0.202125                -0.098972
# Eighth House position              -0.032053                -0.037735
# Eighth House abs_pos                0.198789                -0.101464
# Ninth House sign_num                0.549605                 0.178248
# Ninth House position                0.060968                 0.044042
# Ninth House abs_pos                 0.552483                 0.181133
# Tenth House sign_num                0.996458                 0.533117
# Tenth House position                0.072662                 0.039330
# Tenth House abs_pos                 1.000000                 0.535050
# Eleventh House sign_num             0.535050                 1.000000
# Eleventh House position            -0.007598                -0.019470
# Eleventh House abs_pos              0.533215                 0.996106
# Twelfth House sign_num              0.159606                 0.504366
# Twelfth House position             -0.037140                -0.043390
# Twelfth House abs_pos               0.156031                 0.499950
#
#                          Eleventh House position  Eleventh House abs_pos  \
# Latitude                                0.003864               -0.000437
# Longitude                               0.002182                0.001434
# Magnitude                              -0.004185                0.000279
# Year                                    0.000062               -0.003497
# Month                                  -0.003314               -0.002565
# Day                                    -0.000398               -0.002709
# Hour                                    0.003650               -0.030988
# Minute                                  0.006464                0.002650
# BigEarthquake                          -0.004265                0.000130
# Sun sign_num                           -0.001556                0.000481
# Sun position                           -0.001055               -0.002570
# Sun abs_pos                            -0.001638                0.000266
# Sun retrograde                               NaN                     NaN
# Moon sign_num                           0.000220                0.001160
# Moon position                          -0.002145               -0.001685
# Moon abs_pos                            0.000040                0.001015
# Moon retrograde                              NaN                     NaN
# Mercury sign_num                        0.000647                0.000929
# Mercury position                       -0.006115                0.000516
# Mercury abs_pos                         0.000131                0.000970
# Mercury retrograde                      0.000158               -0.002043
# Venus sign_num                         -0.001924               -0.000813
# Venus position                          0.001328               -0.000660
# Venus abs_pos                          -0.001807               -0.000865
# Venus retrograde                       -0.001968                0.006068
# Mars sign_num                           0.002809               -0.005264
# Mars position                           0.002186                0.000828
# Mars abs_pos                            0.002991               -0.005172
# Mars retrograde                        -0.000778                0.000553
# Jupiter sign_num                        0.002801                0.000031
# Jupiter position                        0.002568               -0.002575
# Jupiter abs_pos                         0.002999               -0.000177
# Jupiter retrograde                     -0.002813               -0.001656
# Saturn sign_num                        -0.006628                0.000332
# Saturn position                        -0.000994                0.001762
# Saturn abs_pos                         -0.006714                0.000495
# Saturn retrograde                      -0.002482                0.002757
# Uranus sign_num                         0.003411                0.000252
# Uranus position                        -0.009401                0.006700
# Uranus abs_pos                          0.002452                0.000883
# Uranus retrograde                       0.000881                0.003003
# Neptune sign_num                       -0.000139               -0.003839
# Neptune position                        0.000764                0.002257
# Neptune abs_pos                         0.000098               -0.003220
# Neptune retrograde                     -0.000775               -0.000354
# Pluto sign_num                         -0.000007               -0.003114
# Pluto position                          0.000709               -0.000416
# Pluto abs_pos                           0.000190               -0.003410
# Pluto retrograde                        0.003150                0.006241
# Mean_Node sign_num                      0.002820               -0.000301
# Mean_Node position                     -0.002733                0.001465
# Mean_Node abs_pos                       0.002582               -0.000176
# Mean_Node retrograde                         NaN                     NaN
# True_Node sign_num                      0.002254               -0.000325
# True_Node position                      0.000258                0.003974
# True_Node abs_pos                       0.002274                0.000014
# True_Node retrograde                    0.002656               -0.005306
# First House sign_num                   -0.033630                0.126066
# First House position                   -0.003651                0.042332
# First House abs_pos                    -0.033993                0.130246
# Second House sign_num                   0.001052               -0.121097
# Second House position                  -0.163642               -0.052083
# Second House abs_pos                   -0.014113               -0.125781
# Third House sign_num                    0.039369               -0.318823
# Third House position                   -0.191712                0.027042
# Third House abs_pos                     0.022457               -0.315824
# Fourth House sign_num                   0.051415               -0.460689
# Fourth House position                   0.126474                0.050396
# Fourth House abs_pos                    0.061825               -0.454905
# Fifth House sign_num                    0.000670               -0.530681
# Fifth House position                    1.000000                0.068749
# Fifth House abs_pos                     0.080810               -0.523436
# Sixth House sign_num                    0.047625               -0.489465
# Sixth House position                    0.087989               -0.035537
# Sixth House abs_pos                     0.054205               -0.490098
# Seventh House sign_num                  0.015051               -0.337127
# Seventh House position                 -0.003651                0.042332
# Seventh House abs_pos                   0.014709               -0.332393
# Eighth House sign_num                  -0.006626               -0.099340
# Eighth House position                  -0.163642               -0.052083
# Eighth House abs_pos                   -0.019233               -0.102939
# Ninth House sign_num                   -0.013883                0.176636
# Ninth House position                   -0.191712                0.027042
# Ninth House abs_pos                    -0.029243                0.178160
# Tenth House sign_num                   -0.018281                0.530344
# Tenth House position                    0.126474                0.050396
# Tenth House abs_pos                    -0.007598                0.533215
# Eleventh House sign_num                -0.019470                0.996106
# Eleventh House position                 1.000000                0.068749
# Eleventh House abs_pos                  0.068749                1.000000
# Twelfth House sign_num                 -0.017628                0.501714
# Twelfth House position                  0.087989               -0.035537
# Twelfth House abs_pos                  -0.009430                0.498030
#
#                          Twelfth House sign_num  Twelfth House position  \
# Latitude                               0.001880                0.002324
# Longitude                             -0.001894               -0.001153
# Magnitude                              0.002161               -0.007084
# Year                                   0.004264               -0.003412
# Month                                 -0.000256                0.005423
# Day                                    0.000759                0.001397
# Hour                                  -0.006747                0.003193
# Minute                                -0.003048               -0.000745
# BigEarthquake                          0.002037               -0.006991
# Sun sign_num                           0.003900                0.000987
# Sun position                          -0.002751               -0.002355
# Sun abs_pos                            0.003659                0.000788
# Sun retrograde                              NaN                     NaN
# Moon sign_num                          0.000591               -0.000335
# Moon position                         -0.008915                0.005586
# Moon abs_pos                          -0.000156                0.000133
# Moon retrograde                             NaN                     NaN
# Mercury sign_num                       0.003098                0.000812
# Mercury position                       0.003224               -0.001092
# Mercury abs_pos                        0.003361                0.000718
# Mercury retrograde                    -0.004872                0.003277
# Venus sign_num                         0.002273                0.002742
# Venus position                        -0.004673                0.002086
# Venus abs_pos                          0.001877                0.002905
# Venus retrograde                       0.003854               -0.004601
# Mars sign_num                         -0.001082                0.005027
# Mars position                         -0.005272                0.000060
# Mars abs_pos                          -0.001542                0.005013
# Mars retrograde                        0.001049               -0.002694
# Jupiter sign_num                       0.004749                0.001909
# Jupiter position                      -0.000730               -0.003665
# Jupiter abs_pos                        0.004673                0.001606
# Jupiter retrograde                     0.003012               -0.003009
# Saturn sign_num                        0.001067               -0.000904
# Saturn position                        0.001038               -0.005414
# Saturn abs_pos                         0.001162               -0.001406
# Saturn retrograde                      0.002042                0.004438
# Uranus sign_num                        0.000357                0.006060
# Uranus position                        0.002930               -0.001928
# Uranus abs_pos                         0.000627                0.005757
# Uranus retrograde                      0.003676                0.001312
# Neptune sign_num                       0.002781               -0.004225
# Neptune position                       0.004659                0.002913
# Neptune abs_pos                        0.004315               -0.003410
# Neptune retrograde                    -0.001163               -0.000792
# Pluto sign_num                         0.003537               -0.002915
# Pluto position                         0.001691               -0.000122
# Pluto abs_pos                          0.004212               -0.003118
# Pluto retrograde                       0.000691               -0.000329
# Mean_Node sign_num                    -0.003955               -0.004418
# Mean_Node position                     0.001114                0.000240
# Mean_Node abs_pos                     -0.003853               -0.004389
# Mean_Node retrograde                        NaN                     NaN
# True_Node sign_num                    -0.003601               -0.004688
# True_Node position                     0.002425               -0.000219
# True_Node abs_pos                     -0.003390               -0.004701
# True_Node retrograde                  -0.002787               -0.002734
# First House sign_num                   0.470758               -0.036053
# First House position                  -0.004537               -0.025035
# First House abs_pos                    0.470363               -0.038521
# Second House sign_num                  0.128024               -0.026599
# Second House position                 -0.025938               -0.138871
# Second House abs_pos                   0.125469               -0.039437
# Third House sign_num                  -0.119227               -0.034933
# Third House position                   0.002114               -0.160205
# Third House abs_pos                   -0.118808               -0.048933
# Fourth House sign_num                 -0.321579               -0.025151
# Fourth House position                  0.071451               -0.129337
# Fourth House abs_pos                  -0.314506               -0.035890
# Fifth House sign_num                  -0.459561                0.009416
# Fifth House position                  -0.017628                0.087989
# Fifth House abs_pos                   -0.459471                0.016437
# Sixth House sign_num                  -0.537531                0.017251
# Sixth House position                  -0.038447                1.000000
# Sixth House abs_pos                   -0.538181                0.094289
# Seventh House sign_num                -0.492803                0.017533
# Seventh House position                -0.004537               -0.025035
# Seventh House abs_pos                 -0.490821                0.015589
# Eighth House sign_num                 -0.319882               -0.021000
# Eighth House position                 -0.025938               -0.138871
# Eighth House abs_pos                  -0.320522               -0.031634
# Ninth House sign_num                  -0.106527               -0.032254
# Ninth House position                   0.002114               -0.160205
# Ninth House abs_pos                   -0.105964               -0.045014
# Tenth House sign_num                   0.153994               -0.026332
# Tenth House position                   0.071451               -0.129337
# Tenth House abs_pos                    0.159606               -0.037140
# Eleventh House sign_num                0.504366               -0.043390
# Eleventh House position               -0.017628                0.087989
# Eleventh House abs_pos                 0.501714               -0.035537
# Twelfth House sign_num                 1.000000               -0.038447
# Twelfth House position                -0.038447                1.000000
# Twelfth House abs_pos                  0.995671                0.054598
#
#                          Twelfth House abs_pos
# Latitude                              0.002095
# Longitude                            -0.001999
# Magnitude                             0.001500
# Year                                  0.003943
# Month                                 0.000248
# Day                                   0.000889
# Hour                                 -0.006445
# Minute                               -0.003115
# BigEarthquake                         0.001385
# Sun sign_num                          0.003989
# Sun position                         -0.002969
# Sun abs_pos                           0.003730
# Sun retrograde                             NaN
# Moon sign_num                         0.000559
# Moon position                        -0.008388
# Moon abs_pos                         -0.000144
# Moon retrograde                            NaN
# Mercury sign_num                      0.003171
# Mercury position                      0.003120
# Mercury abs_pos                       0.003425
# Mercury retrograde                   -0.004564
# Venus sign_num                        0.002526
# Venus position                       -0.004475
# Venus abs_pos                         0.002146
# Venus retrograde                      0.003423
# Mars sign_num                        -0.000614
# Mars position                        -0.005263
# Mars abs_pos                         -0.001074
# Mars retrograde                       0.000798
# Jupiter sign_num                      0.004923
# Jupiter position                     -0.001070
# Jupiter abs_pos                       0.004819
# Jupiter retrograde                    0.002730
# Saturn sign_num                       0.000982
# Saturn position                       0.000533
# Saturn abs_pos                        0.001031
# Saturn retrograde                     0.002453
# Uranus sign_num                       0.000920
# Uranus position                       0.002749
# Uranus abs_pos                        0.001162
# Uranus retrograde                     0.003796
# Neptune sign_num                      0.002386
# Neptune position                      0.004927
# Neptune abs_pos                       0.003995
# Neptune retrograde                   -0.001236
# Pluto sign_num                        0.003263
# Pluto position                        0.001679
# Pluto abs_pos                         0.003919
# Pluto retrograde                      0.000660
# Mean_Node sign_num                   -0.004363
# Mean_Node position                    0.001135
# Mean_Node abs_pos                    -0.004258
# Mean_Node retrograde                       NaN
# True_Node sign_num                   -0.004034
# True_Node position                    0.002403
# True_Node abs_pos                    -0.003825
# True_Node retrograde                 -0.003039
# First House sign_num                  0.467051
# First House position                 -0.006862
# First House abs_pos                   0.466426
# Second House sign_num                 0.125453
# Second House position                -0.038836
# Second House abs_pos                  0.121707
# Third House sign_num                 -0.122387
# Third House position                 -0.012790
# Third House abs_pos                  -0.123270
# Fourth House sign_num                -0.323676
# Fourth House position                 0.059367
# Fourth House abs_pos                 -0.317607
# Fifth House sign_num                 -0.458339
# Fifth House position                 -0.009430
# Fifth House abs_pos                  -0.457596
# Sixth House sign_num                 -0.535522
# Sixth House position                  0.054598
# Sixth House abs_pos                  -0.529005
# Seventh House sign_num               -0.490801
# Seventh House position               -0.006862
# Seventh House abs_pos                -0.489002
# Eighth House sign_num                -0.321594
# Eighth House position                -0.038836
# Eighth House abs_pos                 -0.323223
# Ninth House sign_num                 -0.109446
# Ninth House position                 -0.012790
# Ninth House abs_pos                  -0.110072
# Tenth House sign_num                  0.151429
# Tenth House position                  0.059367
# Tenth House abs_pos                   0.156031
# Eleventh House sign_num               0.499950
# Eleventh House position              -0.009430
# Eleventh House abs_pos                0.498030
# Twelfth House sign_num                0.995671
# Twelfth House position                0.054598
# Twelfth House abs_pos                 1.000000
#
# [93 rows x 93 columns]

# %% [markdown]
# No single feature seems to be correlated to big earthquake either.

# %% [markdown]
# <hr>

# %% [markdown]
# # Modelling with all features

# %% [markdown]
# ## Load latest data and transform for modelling

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("earthquakes1970-2014-5.csv")

# %%
from sklearn import preprocessing

def preprocess_data(dfx):
    df = dfx.copy()
    le = preprocessing.LabelEncoder()
    
    for label, content in df.items():
            if pd.api.types.is_string_dtype(content):
                le.fit(content)
                content2 = le.transform(content)
                df[label] = content2
            if pd.api.types.is_bool_dtype(content):
                df[label] = (df[label] == True).astype(int)
    
    return df

# %%
df = preprocess_data(df)

# %%
df.dtypes
# Out:
# Latitude                     float64
# Longitude                    float64
# Magnitude                    float64
# Year                           int64
# Month                          int64
# Day                            int64
# Hour                           int64
# Minute                         int64
# BigEarthquake                  int64
# Sun quality                    int64
# Sun element                    int64
# Sun sign                       int64
# Sun sign_num                   int64
# Sun position                 float64
# Sun abs_pos                  float64
# Sun point_type                 int64
# Sun house                      int64
# Sun retrograde                 int64
# Moon quality                   int64
# Moon element                   int64
# Moon sign                      int64
# Moon sign_num                  int64
# Moon position                float64
# Moon abs_pos                 float64
# Moon point_type                int64
# Moon house                     int64
# Moon retrograde                int64
# Mercury quality                int64
# Mercury element                int64
# Mercury sign                   int64
# Mercury sign_num               int64
# Mercury position             float64
# Mercury abs_pos              float64
# Mercury point_type             int64
# Mercury house                  int64
# Mercury retrograde             int64
# Venus quality                  int64
# Venus element                  int64
# Venus sign                     int64
# Venus sign_num                 int64
# Venus position               float64
# Venus abs_pos                float64
# Venus point_type               int64
# Venus house                    int64
# Venus retrograde               int64
# Mars quality                   int64
# Mars element                   int64
# Mars sign                      int64
# Mars sign_num                  int64
# Mars position                float64
# Mars abs_pos                 float64
# Mars point_type                int64
# Mars house                     int64
# Mars retrograde                int64
# Jupiter quality                int64
# Jupiter element                int64
# Jupiter sign                   int64
# Jupiter sign_num               int64
# Jupiter position             float64
# Jupiter abs_pos              float64
# Jupiter point_type             int64
# Jupiter house                  int64
# Jupiter retrograde             int64
# Saturn quality                 int64
# Saturn element                 int64
# Saturn sign                    int64
# Saturn sign_num                int64
# Saturn position              float64
# Saturn abs_pos               float64
# Saturn point_type              int64
# Saturn house                   int64
# Saturn retrograde              int64
# Uranus quality                 int64
# Uranus element                 int64
# Uranus sign                    int64
# Uranus sign_num                int64
# Uranus position              float64
# Uranus abs_pos               float64
# Uranus point_type              int64
# Uranus house                   int64
# Uranus retrograde              int64
# Neptune quality                int64
# Neptune element                int64
# Neptune sign                   int64
# Neptune sign_num               int64
# Neptune position             float64
# Neptune abs_pos              float64
# Neptune point_type             int64
# Neptune house                  int64
# Neptune retrograde             int64
# Pluto quality                  int64
# Pluto element                  int64
# Pluto sign                     int64
# Pluto sign_num                 int64
# Pluto position               float64
# Pluto abs_pos                float64
# Pluto point_type               int64
# Pluto house                    int64
# Pluto retrograde               int64
# Mean_Node quality              int64
# Mean_Node element              int64
# Mean_Node sign                 int64
# Mean_Node sign_num             int64
# Mean_Node position           float64
# Mean_Node abs_pos            float64
# Mean_Node point_type           int64
# Mean_Node house                int64
# Mean_Node retrograde           int64
# True_Node quality              int64
# True_Node element              int64
# True_Node sign                 int64
# True_Node sign_num             int64
# True_Node position           float64
# True_Node abs_pos            float64
# True_Node point_type           int64
# True_Node house                int64
# True_Node retrograde           int64
# First House quality            int64
# First House element            int64
# First House sign               int64
# First House sign_num           int64
# First House position         float64
# First House abs_pos          float64
# First House point_type         int64
# Second House quality           int64
# Second House element           int64
# Second House sign              int64
# Second House sign_num          int64
# Second House position        float64
# Second House abs_pos         float64
# Second House point_type        int64
# Third House quality            int64
# Third House element            int64
# Third House sign               int64
# Third House sign_num           int64
# Third House position         float64
# Third House abs_pos          float64
# Third House point_type         int64
# Fourth House quality           int64
# Fourth House element           int64
# Fourth House sign              int64
# Fourth House sign_num          int64
# Fourth House position        float64
# Fourth House abs_pos         float64
# Fourth House point_type        int64
# Fifth House quality            int64
# Fifth House element            int64
# Fifth House sign               int64
# Fifth House sign_num           int64
# Fifth House position         float64
# Fifth House abs_pos          float64
# Fifth House point_type         int64
# Sixth House quality            int64
# Sixth House element            int64
# Sixth House sign               int64
# Sixth House sign_num           int64
# Sixth House position         float64
# Sixth House abs_pos          float64
# Sixth House point_type         int64
# Seventh House quality          int64
# Seventh House element          int64
# Seventh House sign             int64
# Seventh House sign_num         int64
# Seventh House position       float64
# Seventh House abs_pos        float64
# Seventh House point_type       int64
# Eighth House quality           int64
# Eighth House element           int64
# Eighth House sign              int64
# Eighth House sign_num          int64
# Eighth House position        float64
# Eighth House abs_pos         float64
# Eighth House point_type        int64
# Ninth House quality            int64
# Ninth House element            int64
# Ninth House sign               int64
# Ninth House sign_num           int64
# Ninth House position         float64
# Ninth House abs_pos          float64
# Ninth House point_type         int64
# Tenth House quality            int64
# Tenth House element            int64
# Tenth House sign               int64
# Tenth House sign_num           int64
# Tenth House position         float64
# Tenth House abs_pos          float64
# Tenth House point_type         int64
# Eleventh House quality         int64
# Eleventh House element         int64
# Eleventh House sign            int64
# Eleventh House sign_num        int64
# Eleventh House position      float64
# Eleventh House abs_pos       float64
# Eleventh House point_type      int64
# Twelfth House quality          int64
# Twelfth House element          int64
# Twelfth House sign             int64
# Twelfth House sign_num         int64
# Twelfth House position       float64
# Twelfth House abs_pos        float64
# Twelfth House point_type       int64
# dtype: object

# %%
df.head().T
# Out:
#                                      0            1            2            3  \
# Latitude                    -36.010840    75.182840     2.812124    61.617633
# Longitude                    75.813176   147.876041   -69.186252    27.608128
# Magnitude                     0.000000     0.000000     0.000000     0.000000
# Mercury house                 6.000000
# Mercury retrograde            0.000000
# Venus quality                 2.000000
# Venus element                 1.000000
# Venus sign                   11.000000
# Venus sign_num                5.000000
# Venus position               11.696692
# Venus abs_pos               161.696692
# Venus point_type              0.000000
# Venus house                  10.000000
# Venus retrograde              0.000000
# Mars quality                  1.000000
# Mars element                  1.000000
# Mars sign                    10.000000
# Mars sign_num                 1.000000
# Mars position                23.954396
# Mars abs_pos                 53.954396
# Mars point_type               0.000000
# Mars house                    1.000000
# Mars retrograde               0.000000
# Jupiter quality               0.000000
# Jupiter element               2.000000
# Jupiter sign                  1.000000
# Jupiter sign_num              0.000000
# Jupiter position             24.554566
# Jupiter abs_pos              24.554566
# Jupiter point_type            0.000000
# Jupiter house                 1.000000
# Jupiter retrograde            0.000000
# Saturn quality                0.000000
# Saturn element                3.000000
# Saturn sign                   2.000000
# Saturn sign_num               3.000000
# Saturn position              25.160833
# Saturn abs_pos              115.160833
# Saturn point_type             0.000000
# Saturn house                  3.000000
# Saturn retrograde             0.000000
# Uranus quality                0.000000
# Uranus element                0.000000
# Uranus sign                   3.000000
# Uranus sign_num               6.000000
# Uranus position              28.726176
# Uranus abs_pos              208.726176
# Uranus point_type             0.000000
# Uranus house                  2.000000
# Uranus retrograde             0.000000
# Neptune quality               2.000000
# Neptune element               2.000000
# Neptune sign                  3.000000
# Neptune sign_num              8.000000
# Neptune position              9.092788
# Neptune abs_pos             249.092788
# Neptune point_type            0.000000
# Neptune house                 8.000000
# Neptune retrograde            1.000000
# Pluto quality                 0.000000
# Pluto element                 0.000000
# Pluto sign                    1.000000
# Pluto sign_num                6.000000
# Pluto position                7.128052
# Pluto abs_pos               187.128052
# Pluto point_type              0.000000
# Pluto house                   4.000000
# Pluto retrograde              0.000000
# Mean_Node quality             1.000000
# Mean_Node element             3.000000
# Mean_Node sign                9.000000
# Mean_Node sign_num            7.000000
# Mean_Node position           27.142666
# Mean_Node abs_pos           237.142666
# Mean_Node point_type          0.000000
# Mean_Node house               2.000000
# Mean_Node retrograde          1.000000
# True_Node quality             1.000000
# True_Node element             3.000000
# True_Node sign                9.000000
# True_Node sign_num            7.000000
# True_Node position           28.053390
# True_Node abs_pos           238.053390
# True_Node point_type          0.000000
# True_Node house               2.000000
# True_Node retrograde          1.000000
# First House quality           0.000000
# First House element           3.000000
# First House sign              2.000000
# First House sign_num          3.000000
# First House position         10.131841
# First House abs_pos         100.131841
# First House point_type        0.000000
# Second House quality          0.000000
# Second House element          3.000000
# Second House sign             2.000000
# Second House sign_num         3.000000
# Second House position        27.996366
# Second House abs_pos        117.996366
# Second House point_type       0.000000
# Third House quality           1.000000
# Third House element           2.000000
# Third House sign              5.000000
# Third House sign_num          4.000000
# Third House position         17.935821
# Third House abs_pos         137.935821
# Third House point_type        0.000000
# Fourth House quality          2.000000
# Fourth House element          1.000000
# Fourth House sign            11.000000
# Fourth House sign_num         5.000000
# Fourth House position        13.525382
# Fourth House abs_pos        163.525382
# Fourth House point_type       0.000000
# Fifth House quality           0.000000
# Fifth House element           0.000000
# Fifth House sign              6.000000
# Fifth House sign_num          6.000000
# Fifth House position         18.854461
# Fifth House abs_pos         198.854461
# Fifth House point_type        0.000000
# Sixth House quality           2.000000
# Sixth House element           2.000000
# Sixth House sign              8.000000
# Sixth House sign_num          8.000000
# Sixth House position          2.209341
# Sixth House abs_pos         242.209341
# Sixth House point_type        0.000000
# Seventh House quality         0.000000
# Seventh House element         1.000000
# Seventh House sign            3.000000
# Seventh House sign_num        9.000000
# Seventh House position       10.131841
# Seventh House abs_pos       280.131841
# Seventh House point_type      0.000000
# Eighth House quality          0.000000
# Eighth House element          1.000000
# Eighth House sign             3.000000
# Eighth House sign_num         9.000000
# Eighth House position        27.996366
# Eighth House abs_pos        297.996366
# Eighth House point_type       0.000000
# Ninth House quality           1.000000
# Ninth House element           0.000000
# Ninth House sign              0.000000
# Ninth House sign_num         10.000000
# Ninth House position         17.935821
# Ninth House abs_pos         317.935821
# Ninth House point_type        0.000000
# Tenth House quality           2.000000
# Tenth House element           3.000000
# Tenth House sign              7.000000
# Tenth House sign_num         11.000000
# Tenth House position         13.525382
# Tenth House abs_pos         343.525382
# Tenth House point_type        0.000000
# Eleventh House quality        0.000000
# Eleventh House element        2.000000
# Eleventh House sign           1.000000
# Eleventh House sign_num       0.000000
# Eleventh House position      18.854461
# Eleventh House abs_pos       18.854461
# Eleventh House point_type     0.000000
# Twelfth House quality         2.000000
# Twelfth House element         0.000000
# Twelfth House sign            4.000000
# Twelfth House sign_num        2.000000
# Twelfth House position        2.209341
# Twelfth House abs_pos        62.209341
# Twelfth House point_type      0.000000

# %%
df.to_csv("earthquakes1970-2014-6.csv", index=False)

# %% [markdown]
# ## Train - test split

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("earthquakes1970-2014-6.csv")

df_eq = df[df["BigEarthquake"] == 1]
df_eq.sample()
X_eq = df_eq.drop("Magnitude", axis=1).drop("BigEarthquake", axis=1)
y_eq = df_eq["BigEarthquake"]

df_ne = df[df["BigEarthquake"] == 0]
df_ne.sample()
X_ne = df_ne.drop("Magnitude", axis=1).drop("BigEarthquake", axis=1)
y_ne = df_ne["BigEarthquake"]

len(X_eq), len(X_ne)
# Out:
# (5304, 115214)

# %%
# y_eq.head()

# %%
X_train = X_ne.copy()
y_train = y_ne.copy()
X_eq_train, X_eq_test, y_eq_train, y_eq_test = train_test_split(X_eq, y_eq, test_size=0.2)
X_train = pd.concat([X_train, X_eq_train], ignore_index=True)
y_train = pd.concat([y_train, y_eq_train], ignore_index=True)
X_test = X_eq_test.copy()
y_test = y_eq_test.copy()

# %%
# len(X_train), len(y_train), len(X_test), len(y_test)

# %%
# y_test.head()

# %%
# X_train.dtypes

# %%
# y_train.dtypes

# %%
# y_test.head()

# %%
# len(y_test[y_test == 1]) / len(y_test), len(y_test[y_test == 0]) / len(y_test)

# %%
# len(y_train[y_train == 1]) / len(y_train), len(y_train[y_train == 0]) / len(y_train)

# %%
# len(y_train[y_train == 1])

# %% [markdown]
# ## Predict big earthquake

# %% [markdown]
# ### SGD Classifier

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=5)
clf.fit(X_train, y_train)
# Out:
# /Users/kerem/Documents/dev/kaggle/env/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:702: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDClassifier(max_iter=5)

# %%
clf.score(X_test, y_test)
# Out:
# 0.0

# %% [markdown]
# ### Kernel approximation

# %%
from sklearn.kernel_approximation import RBFSampler
from sklearn.linear_model import SGDClassifier

rbf_feature = RBFSampler(gamma=1, random_state=1)
X_features = rbf_feature.fit_transform(X)
clf = SGDClassifier(max_iter=5)
clf.fit(X_train, y_train)
# Out:
# /Users/kerem/Documents/dev/kaggle/env/lib/python3.11/site-packages/sklearn/linear_model/_stochastic_gradient.py:702: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# SGDClassifier(max_iter=5)

# %%
clf.score(X_test, y_test)
# Out:
# 0.0

# %% [markdown]
# ### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
clf.score(X_test, y_test)
# Out:
# 0.046182846371347785

# %% [markdown]
# ### KNeighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
clf = KNeighborsClassifier()
clf.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
clf.score(X_test, y_test)

# %% [markdown]
# Kernel dies, I don't know why.

# %% [markdown]
# ### Linear SVC

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
clf.score(X_test, y_test)
# Out:
# 0.0

# %% [markdown]
# ### Logistic regression

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()
clf.fit(X_train, y_train)
# Out:
# /Users/kerem/Documents/dev/kaggle/env/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
clf.score(X_test, y_test)
# Out:
# 0.0

# %% [markdown]
# # Modelling with partial features
#
# No good results, so far. Random forest seems to bring the "best" (!) result, so we will stick to it. I will try to cherry-pick features to be involved.

# %% [markdown]
# ## astro.com features
#
# https://www.astro.com/astrology/aa_article140925_e.htm says: Astrologers consider Pluto an essential influence in earthquakes, which cause a tremendous upheaval, as in this case. Uranus can be involved, because of its sudden, unexpected and drastic character. When Jupiter is involved, the effects of an earthquake will be of a large, massive nature, as we have seen here. And when Neptune is involved, the oceans can be so moved as to cause tsunamis. The planet Mars also has to be considered, as it causes shocks and breaks things up. It can also cause fires, as was the case in Lisbon.
#
# So I will re-attempt to build a model using those planets.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("earthquakes1970-2014-5.csv")

# %%
df = preprocess_data(df)

# %%
pd.options.display.max_rows = 4000
df.dtypes
# Out:
# Latitude                     float64
# Longitude                    float64
# Magnitude                    float64
# Year                           int64
# Month                          int64
# Day                            int64
# Hour                           int64
# Minute                         int64
# BigEarthquake                  int64
# Sun quality                    int64
# Sun element                    int64
# Sun sign                       int64
# Sun sign_num                   int64
# Sun position                 float64
# Sun abs_pos                  float64
# Sun point_type                 int64
# Sun house                      int64
# Sun retrograde                 int64
# Moon quality                   int64
# Moon element                   int64
# Moon sign                      int64
# Moon sign_num                  int64
# Moon position                float64
# Moon abs_pos                 float64
# Moon point_type                int64
# Moon house                     int64
# Moon retrograde                int64
# Mercury quality                int64
# Mercury element                int64
# Mercury sign                   int64
# Mercury sign_num               int64
# Mercury position             float64
# Mercury abs_pos              float64
# Mercury point_type             int64
# Mercury house                  int64
# Mercury retrograde             int64
# Venus quality                  int64
# Venus element                  int64
# Venus sign                     int64
# Venus sign_num                 int64
# Venus position               float64
# Venus abs_pos                float64
# Venus point_type               int64
# Venus house                    int64
# Venus retrograde               int64
# Mars quality                   int64
# Mars element                   int64
# Mars sign                      int64
# Mars sign_num                  int64
# Mars position                float64
# Mars abs_pos                 float64
# Mars point_type                int64
# Mars house                     int64
# Mars retrograde                int64
# Jupiter quality                int64
# Jupiter element                int64
# Jupiter sign                   int64
# Jupiter sign_num               int64
# Jupiter position             float64
# Jupiter abs_pos              float64
# Jupiter point_type             int64
# Jupiter house                  int64
# Jupiter retrograde             int64
# Saturn quality                 int64
# Saturn element                 int64
# Saturn sign                    int64
# Saturn sign_num                int64
# Saturn position              float64
# Saturn abs_pos               float64
# Saturn point_type              int64
# Saturn house                   int64
# Saturn retrograde              int64
# Uranus quality                 int64
# Uranus element                 int64
# Uranus sign                    int64
# Uranus sign_num                int64
# Uranus position              float64
# Uranus abs_pos               float64
# Uranus point_type              int64
# Uranus house                   int64
# Uranus retrograde              int64
# Neptune quality                int64
# Neptune element                int64
# Neptune sign                   int64
# Neptune sign_num               int64
# Neptune position             float64
# Neptune abs_pos              float64
# Neptune point_type             int64
# Neptune house                  int64
# Neptune retrograde             int64
# Pluto quality                  int64
# Pluto element                  int64
# Pluto sign                     int64
# Pluto sign_num                 int64
# Pluto position               float64
# Pluto abs_pos                float64
# Pluto point_type               int64
# Pluto house                    int64
# Pluto retrograde               int64
# Mean_Node quality              int64
# Mean_Node element              int64
# Mean_Node sign                 int64
# Mean_Node sign_num             int64
# Mean_Node position           float64
# Mean_Node abs_pos            float64
# Mean_Node point_type           int64
# Mean_Node house                int64
# Mean_Node retrograde           int64
# True_Node quality              int64
# True_Node element              int64
# True_Node sign                 int64
# True_Node sign_num             int64
# True_Node position           float64
# True_Node abs_pos            float64
# True_Node point_type           int64
# True_Node house                int64
# True_Node retrograde           int64
# First House quality            int64
# First House element            int64
# First House sign               int64
# First House sign_num           int64
# First House position         float64
# First House abs_pos          float64
# First House point_type         int64
# Second House quality           int64
# Second House element           int64
# Second House sign              int64
# Second House sign_num          int64
# Second House position        float64
# Second House abs_pos         float64
# Second House point_type        int64
# Third House quality            int64
# Third House element            int64
# Third House sign               int64
# Third House sign_num           int64
# Third House position         float64
# Third House abs_pos          float64
# Third House point_type         int64
# Fourth House quality           int64
# Fourth House element           int64
# Fourth House sign              int64
# Fourth House sign_num          int64
# Fourth House position        float64
# Fourth House abs_pos         float64
# Fourth House point_type        int64
# Fifth House quality            int64
# Fifth House element            int64
# Fifth House sign               int64
# Fifth House sign_num           int64
# Fifth House position         float64
# Fifth House abs_pos          float64
# Fifth House point_type         int64
# Sixth House quality            int64
# Sixth House element            int64
# Sixth House sign               int64
# Sixth House sign_num           int64
# Sixth House position         float64
# Sixth House abs_pos          float64
# Sixth House point_type         int64
# Seventh House quality          int64
# Seventh House element          int64
# Seventh House sign             int64
# Seventh House sign_num         int64
# Seventh House position       float64
# Seventh House abs_pos        float64
# Seventh House point_type       int64
# Eighth House quality           int64
# Eighth House element           int64
# Eighth House sign              int64
# Eighth House sign_num          int64
# Eighth House position        float64
# Eighth House abs_pos         float64
# Eighth House point_type        int64
# Ninth House quality            int64
# Ninth House element            int64
# Ninth House sign               int64
# Ninth House sign_num           int64
# Ninth House position         float64
# Ninth House abs_pos          float64
# Ninth House point_type         int64
# Tenth House quality            int64
# Tenth House element            int64
# Tenth House sign               int64
# Tenth House sign_num           int64
# Tenth House position         float64
# Tenth House abs_pos          float64
# Tenth House point_type         int64
# Eleventh House quality         int64
# Eleventh House element         int64
# Eleventh House sign            int64
# Eleventh House sign_num        int64
# Eleventh House position      float64
# Eleventh House abs_pos       float64
# Eleventh House point_type      int64
# Twelfth House quality          int64
# Twelfth House element          int64
# Twelfth House sign             int64
# Twelfth House sign_num         int64
# Twelfth House position       float64
# Twelfth House abs_pos        float64
# Twelfth House point_type       int64
# dtype: object

# %%
dfp = pd.DataFrame()

# %%
features = ["Latitude", 
            "Longitude",
            "Year",
            "Month",
            "Day",
            "Hour",
            "Minute",
            "BigEarthquake"]

planets = ["Pluto", "Uranus", "Jupiter", "Mars"]

# %%
dfp = pd.DataFrame()

for column in df.columns:
    if column in features:
        dfp[column] = df[column]
        continue
    for planet in planets:
        if planet in column:
            dfp[column] = df[column]
            continue
            
dfp.dtypes
# Out:
# Latitude              float64
# Longitude             float64
# Year                    int64
# Month                   int64
# Day                     int64
# Hour                    int64
# Minute                  int64
# BigEarthquake           int64
# Mars quality            int64
# Mars element            int64
# Mars sign               int64
# Mars sign_num           int64
# Mars position         float64
# Mars abs_pos          float64
# Mars point_type         int64
# Mars house              int64
# Mars retrograde         int64
# Jupiter quality         int64
# Jupiter element         int64
# Jupiter sign            int64
# Jupiter sign_num        int64
# Jupiter position      float64
# Jupiter abs_pos       float64
# Jupiter point_type      int64
# Jupiter house           int64
# Jupiter retrograde      int64
# Uranus quality          int64
# Uranus element          int64
# Uranus sign             int64
# Uranus sign_num         int64
# Uranus position       float64
# Uranus abs_pos        float64
# Uranus point_type       int64
# Uranus house            int64
# Uranus retrograde       int64
# Pluto quality           int64
# Pluto element           int64
# Pluto sign              int64
# Pluto sign_num          int64
# Pluto position        float64
# Pluto abs_pos         float64
# Pluto point_type        int64
# Pluto house             int64
# Pluto retrograde        int64
# dtype: object

# %%
dfp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120518 entries, 0 to 120517
# Data columns (total 44 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Latitude            120518 non-null  float64
#  1   Longitude           120518 non-null  float64
#  2   Year                120518 non-null  int64
#  3   Month               120518 non-null  int64
#  4   Day                 120518 non-null  int64
#  5   Hour                120518 non-null  int64
#  6   Minute              120518 non-null  int64
#  7   BigEarthquake       120518 non-null  int64
#  8   Mars quality        120518 non-null  int64
#  9   Mars element        120518 non-null  int64
#  10  Mars sign           120518 non-null  int64
#  11  Mars sign_num       120518 non-null  int64
#  12  Mars position       120518 non-null  float64
#  13  Mars abs_pos        120518 non-null  float64
#  14  Mars point_type     120518 non-null  int64
#  15  Mars house          120518 non-null  int64
#  16  Mars retrograde     120518 non-null  int64
#  17  Jupiter quality     120518 non-null  int64
#  18  Jupiter element     120518 non-null  int64
#  19  Jupiter sign        120518 non-null  int64
#  20  Jupiter sign_num    120518 non-null  int64
#  21  Jupiter position    120518 non-null  float64
#  22  Jupiter abs_pos     120518 non-null  float64
#  23  Jupiter point_type  120518 non-null  int64
#  24  Jupiter house       120518 non-null  int64
#  25  Jupiter retrograde  120518 non-null  int64
#  26  Uranus quality      120518 non-null  int64
#  27  Uranus element      120518 non-null  int64
#  28  Uranus sign         120518 non-null  int64
#  29  Uranus sign_num     120518 non-null  int64
#  30  Uranus position     120518 non-null  float64
#  31  Uranus abs_pos      120518 non-null  float64
#  32  Uranus point_type   120518 non-null  int64
#  33  Uranus house        120518 non-null  int64
#  34  Uranus retrograde   120518 non-null  int64
#  35  Pluto quality       120518 non-null  int64
#  36  Pluto element       120518 non-null  int64
#  37  Pluto sign          120518 non-null  int64
#  38  Pluto sign_num      120518 non-null  int64
#  39  Pluto position      120518 non-null  float64
#  40  Pluto abs_pos       120518 non-null  float64
#  41  Pluto point_type    120518 non-null  int64
#  42  Pluto house         120518 non-null  int64
#  43  Pluto retrograde    120518 non-null  int64
# dtypes: float64(10), int64(34)
# memory usage: 40.5 MB

# %%
df_eq = dfp[dfp["BigEarthquake"] == 1]
df_eq.sample()
X_eq = df_eq.drop("BigEarthquake", axis=1)
y_eq = df_eq["BigEarthquake"]

df_ne = dfp[dfp["BigEarthquake"] == 0]
df_ne.sample()
X_ne = df_ne.drop("BigEarthquake", axis=1)
y_ne = df_ne["BigEarthquake"]

len(X_eq), len(X_ne)
# Out:
# (5304, 115214)

# %%
from sklearn.model_selection import train_test_split

X_train = X_ne.copy()
y_train = y_ne.copy()
X_eq_train, X_eq_test, y_eq_train, y_eq_test = train_test_split(X_eq, y_eq, test_size=0.2)
X_train = pd.concat([X_train, X_eq_train], ignore_index=True)
y_train = pd.concat([y_train, y_eq_train], ignore_index=True)
X_test = X_eq_test.copy()
y_test = y_eq_test.copy()

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.11592836946277098

# %% [markdown]
# Better than before, but not high enough.

# %% [markdown]
# ## shankerstudy.com features
#
# https://www.shankerstudy.com/2010/05/earthquakes-astrological-princliples.html says:
#
# At the time of earth-quakes, adverse connections between Mars and Saturn (conjunction, opposition, aspect etc.) have been noted.
#
# Frequent happening of earthquakes is indicated when the planets like Uranus, Saturn, Mars, or Jupiter occupy Taurus and Scorpio.
#
# For an earthquake to happen in the year, severe affliction of 8th house or its lord must be indicated (8th house denotes mass deaths and mass tragedies which do happen in earthquakes also).
#
# Eclipses falling at quadrants to Jupiter, Saturn or Mars also produce earthquakes. The area of the occurrence is generally indicated by the zodiacal sign in which the above combination occur.
#
# The Moon and Mercury have a significant role to play in causing earthquakes.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv("earthquakes1970-2014-5.csv")
df = preprocess_data(df)
dfp = pd.DataFrame()

# %%
def run_theories(df, features, theories):
    theory_index = 0
    for theory in theories:
        theory_index += 1
        dfp = pd.DataFrame()

        for column in df.columns:
            if column in features:
                dfp[column] = df[column]
                continue
            for entry in theory:
                if entry in column:
                    dfp[column] = df[column]
                    continue

        df_eq = dfp[dfp["BigEarthquake"] == 1]
        df_eq.sample()
        X_eq = df_eq.drop("BigEarthquake", axis=1)
        y_eq = df_eq["BigEarthquake"]

        df_ne = dfp[dfp["BigEarthquake"] == 0]
        df_ne.sample()
        X_ne = df_ne.drop("BigEarthquake", axis=1)
        y_ne = df_ne["BigEarthquake"]

        X_train = X_ne.copy()
        y_train = y_ne.copy()
        X_eq_train, X_eq_test, y_eq_train, y_eq_test = train_test_split(X_eq, y_eq, test_size=0.2)
        X_train = pd.concat([X_train, X_eq_train], ignore_index=True)
        y_train = pd.concat([y_train, y_eq_train], ignore_index=True)
        X_test = X_eq_test.copy()
        y_test = y_eq_test.copy()
        
        print(f"Theory {theory_index} columns:{X_train.columns}")

        clf = RandomForestClassifier()
        clf.fit(X_train, y_train)
        print(f"Theory {theory_index} score:{clf.score(X_test, y_test)}")
        print("Feature importances:")
        fi_index = -1
        lat_imp = 0
        lon_imp = 0
        for fim in clf.feature_importances_:
            fi_index += 1
            if dfp.columns[fi_index] == "Latitude":
                lat_imp = fim
            elif dfp.columns[fi_index] == "Longitude":
                lon_imp = fim
            elif (lat_imp > 0 and fim >= lat_imp) or (lon_imp > 0 and fim >= lon_imp):
                print("!!!!!!!!!!")
            print(f"{dfp.columns[fi_index]}: {fim}")
        # print(clf.feature_importances_)

# %%
features = ["Latitude", 
            "Longitude",
            "BigEarthquake"]

theories = [["Mars", "Saturn"],
            ["Uranus", "Saturn", "Mars", "Jupiter"],
            ["Eighth House"],
            ["Saturn", "Mars", "Jupiter"],
            ["Moon", "Mercury"]]

run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Mars quality', 'Mars element', 'Mars sign',
#        'Mars sign_num', 'Mars position', 'Mars abs_pos', 'Mars point_type',
#        'Mars house', 'Mars retrograde', 'Saturn quality', 'Saturn element',
#        'Saturn sign', 'Saturn sign_num', 'Saturn position', 'Saturn abs_pos',
#        'Saturn point_type', 'Saturn house', 'Saturn retrograde'],
#       dtype='object')
# Theory 1 score:0.1950989632422243
# Feature importances:
# Latitude: 0.17226889838358395
# Longitude: 0.18633680831608437
# BigEarthquake: 0.009051386365375913
# Mars quality: 0.012140710815925632
# Mars element: 0.016588371073593344
# Mars sign: 0.01628414057579641
# Mars sign_num: 0.108795148244255
# Mars position: 0.10553554942511323
# Mars abs_pos: 0.0
# Mars point_type: 0.04589892762376599
# Mars house: 0.005779327567468251
# Mars retrograde: 0.008217226557817989
# Saturn quality: 0.009867138772623985
# Saturn element: 0.01306757326929782
# Saturn sign: 0.01372804389120733
# Saturn sign_num: 0.11002831863967676
# Saturn position: 0.11097474220810029
# Saturn abs_pos: 0.0
# Saturn point_type: 0.045745918868458774
# Saturn house: 0.009691769401855056
# Theory 2 columns:Index(['Latitude', 'Longitude', 'Mars quality', 'Mars element', 'Mars sign',
#        'Mars sign_num', 'Mars position', 'Mars abs_pos', 'Mars point_type',
#        'Mars house', 'Mars retrograde', 'Jupiter quality', 'Jupiter element',
#        'Jupiter sign', 'Jupiter sign_num', 'Jupiter position',
#        'Jupiter abs_pos', 'Jupiter point_type', 'Jupiter house',
#        'Jupiter retrograde', 'Saturn quality', 'Saturn element', 'Saturn sign',
#        'Saturn sign_num', 'Saturn position', 'Saturn abs_pos',
#        'Saturn point_type', 'Saturn house', 'Saturn retrograde',
#        'Uranus quality', 'Uranus element', 'Uranus sign', 'Uranus sign_num',
#        'Uranus position', 'Uranus abs_pos', 'Uranus point_type',
#        'Uranus house', 'Uranus retrograde'],
#       dtype='object')
# Theory 2 score:0.15551366635249764
# Feature importances:
# Latitude: 0.1088866888268546
# Longitude: 0.13653532892443954
# BigEarthquake: 0.0065236879955751755
# Mars quality: 0.008126113186646236
# Mars element: 0.011658565631044417
# Mars sign: 0.01093973138992649
# Mars sign_num: 0.06828722480006678
# Mars position: 0.06534615341108492
# Mars abs_pos: 0.0
# Mars point_type: 0.02818640127995793
# Mars house: 0.0028859830076420584
# Mars retrograde: 0.004679355286890433
# Jupiter quality: 0.005187256059724939
# Jupiter element: 0.006920198238890905
# Jupiter sign: 0.006647972233999296
# Jupiter sign_num: 0.06617021511920271
# Jupiter position: 0.06601749104311176
# Jupiter abs_pos: 0.0
# Jupiter point_type: 0.027698847040724422
# Jupiter house: 0.0042495369190751
# Jupiter retrograde: 0.003131950807470457
# Saturn quality: 0.003629118146155979
# Saturn element: 0.004603658262613468
# Saturn sign: 0.00470633099439408
# Saturn sign_num: 0.06692840564826927
# Saturn position: 0.06713194594718963
# Saturn abs_pos: 0.0
# Saturn point_type: 0.02675142738740528
# Saturn house: 0.004561435211167459
# Saturn retrograde: 0.001843525734176514
# Uranus quality: 0.001924678730120845
# Uranus element: 0.0029513736422793462
# Uranus sign: 0.0037831849658354474
# Uranus sign_num: 0.0680813898691718
# Uranus position: 0.0723683775466935
# Uranus abs_pos: 0.0
# Uranus point_type: 0.027808258796120276
# Uranus house: 0.00484818791607913
# Theory 3 columns:Index(['Latitude', 'Longitude', 'Eighth House quality', 'Eighth House element',
#        'Eighth House sign', 'Eighth House sign_num', 'Eighth House position',
#        'Eighth House abs_pos', 'Eighth House point_type'],
#       dtype='object')
# Theory 3 score:0.27992459943449577
# Feature importances:
# Latitude: 0.3249010450300065
# Longitude: 0.307300819099726
# BigEarthquake: 0.007629392381875487
# Eighth House quality: 0.010190971719180947
# Eighth House element: 0.014412351452596476
# Eighth House sign: 0.013385215641258594
# Eighth House sign_num: 0.16438086730822732
# Eighth House position: 0.15779933736712873
# Eighth House abs_pos: 0.0
# Theory 4 columns:Index(['Latitude', 'Longitude', 'Mars quality', 'Mars element', 'Mars sign',
#        'Mars sign_num', 'Mars position', 'Mars abs_pos', 'Mars point_type',
#        'Mars house', 'Mars retrograde', 'Jupiter quality', 'Jupiter element',
#        'Jupiter sign', 'Jupiter sign_num', 'Jupiter position',
#        'Jupiter abs_pos', 'Jupiter point_type', 'Jupiter house',
#        'Jupiter retrograde', 'Saturn quality', 'Saturn element', 'Saturn sign',
#        'Saturn sign_num', 'Saturn position', 'Saturn abs_pos',
#        'Saturn point_type', 'Saturn house', 'Saturn retrograde'],
#       dtype='object')
# Theory 4 score:0.15551366635249764
# Feature importances:
# Latitude: 0.12882528671484145
# Longitude: 0.15258605281013712
# BigEarthquake: 0.007242661209586696
# Mars quality: 0.00928208870159693
# Mars element: 0.012959259213962284
# Mars sign: 0.012721421485069384
# Mars sign_num: 0.08236945638550087
# Mars position: 0.08028880962446404
# Mars abs_pos: 0.0
# Mars point_type: 0.03528354837980556
# Mars house: 0.0031045538626642533
# Mars retrograde: 0.005793504850884254
# Jupiter quality: 0.00727466494490162
# Jupiter element: 0.01006231369828175
# Jupiter sign: 0.009871095123116777
# Jupiter sign_num: 0.08191004698958386
# Jupiter position: 0.08257391054275386
# Jupiter abs_pos: 0.0
# Jupiter point_type: 0.033900040899419
# Jupiter house: 0.006014555789011406
# Jupiter retrograde: 0.0049354023869634615
# Saturn quality: 0.006958507057861132
# Saturn element: 0.009026797536849583
# Saturn sign: 0.00945066819237656
# Saturn sign_num: 0.08281650953312336
# Saturn position: 0.08413344268320432
# Saturn abs_pos: 0.0
# Saturn point_type: 0.03420498775998206
# Saturn house: 0.006410413624058493
# Theory 5 columns:Index(['Latitude', 'Longitude', 'Moon quality', 'Moon element', 'Moon sign',
#        'Moon sign_num', 'Moon position', 'Moon abs_pos', 'Moon point_type',
#        'Moon house', 'Moon retrograde', 'Mercury quality', 'Mercury element',
#        'Mercury sign', 'Mercury sign_num', 'Mercury position',
#        'Mercury abs_pos', 'Mercury point_type', 'Mercury house',
#        'Mercury retrograde'],
#       dtype='object')
# Theory 5 score:0.07917059377945335
# Feature importances:
# Latitude: 0.17649778155722146
# Longitude: 0.1938455695983341
# BigEarthquake: 0.011848696761213896
# Moon quality: 0.015472221937254673
# Moon element: 0.021092040913418333
# Moon sign: 0.020629278567876476
# Moon sign_num: 0.09994834397427618
# Moon position: 0.09544694627988398
# Moon abs_pos: 0.0
# Moon point_type: 0.04701182728521567
# Moon house: 0.0
# Moon retrograde: 0.009709456005625047
# Mercury quality: 0.013258773361015058
# Mercury element: 0.017950561904048822
# Mercury sign: 0.017995032268970493
# Mercury sign_num: 0.10280563222763414
# Mercury position: 0.09848899584892086
# Mercury abs_pos: 0.0
# Mercury point_type: 0.04732125048357696
# Mercury house: 0.010677591025513942

# %% [markdown]
# Eight House: %26. A little contribution from 8th hough sign_num and position, but not much.

# %% [markdown]
# Let's try Mars alone

# %%
features = ["Latitude", 
            "Longitude",
            "BigEarthquake"]

theories = [["Mars"], 
            ["Mars", "Eighth House"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Mars quality', 'Mars element', 'Mars sign',
#        'Mars sign_num', 'Mars position', 'Mars abs_pos', 'Mars point_type',
#        'Mars house', 'Mars retrograde'],
#       dtype='object')
# Theory 1 score:0.2299717247879359
# Feature importances:
# Latitude: 0.2816197196093665
# Longitude: 0.28270294165893584
# BigEarthquake: 0.006273690643931192
# Mars quality: 0.009018434674702305
# Mars element: 0.01156570398002165
# Mars sign: 0.011414902393917695
# Mars sign_num: 0.16577623328508595
# Mars position: 0.1613149000542286
# Mars abs_pos: 0.0
# Mars point_type: 0.061466862646771675
# Mars house: 0.008846611053038626
# Theory 2 columns:Index(['Latitude', 'Longitude', 'Mars quality', 'Mars element', 'Mars sign',
#        'Mars sign_num', 'Mars position', 'Mars abs_pos', 'Mars point_type',
#        'Mars house', 'Mars retrograde', 'Eighth House quality',
#        'Eighth House element', 'Eighth House sign', 'Eighth House sign_num',
#        'Eighth House position', 'Eighth House abs_pos',
#        'Eighth House point_type'],
#       dtype='object')
# Theory 2 score:0.07822808671065033
# Feature importances:
# Latitude: 0.19809239852793298
# Longitude: 0.2125448661939296
# BigEarthquake: 0.006597335551788437
# Mars quality: 0.009938917395847983
# Mars element: 0.011769876914047852
# Mars sign: 0.011613581004912077
# Mars sign_num: 0.11788472408934743
# Mars position: 0.11203009343665368
# Mars abs_pos: 0.0
# Mars point_type: 0.030949997648607012
# Mars house: 0.00837968440714893
# Mars retrograde: 0.010482826887914127
# Eighth House quality: 0.013028538168434446
# Eighth House element: 0.02060089266574772
# Eighth House sign: 0.01871245247567994
# Eighth House sign_num: 0.11268204111812141
# Eighth House position: 0.10469177351388642
# Eighth House abs_pos: 0.0

# %% [markdown]
# Mars: %23, but little contribution from sign_num and position.

# %%
theories = [["Mars sign_num", "Mars position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Mars sign_num', 'Mars position'], dtype='object')
# Theory 1 score:0.4514608859566447
# Feature importances:
# Latitude: 0.4027226067778099
# Longitude: 0.36234651261956846
# BigEarthquake: 0.06522094123543397
# Mars sign_num: 0.16970993936718773

# %%
theories = [["Mars sign_num"], ["Mars position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Mars sign_num'], dtype='object')
# Theory 1 score:0.41658812441093307
# Feature importances:
# Latitude: 0.49110014421486936
# Longitude: 0.4785959279980758
# BigEarthquake: 0.03030392778705475
# Theory 2 columns:Index(['Latitude', 'Longitude', 'Mars position'], dtype='object')
# Theory 2 score:0.4043355325164939
# Feature importances:
# Latitude: 0.3907983965074198
# Longitude: 0.38564507971285533
# BigEarthquake: 0.22355652377972482

# %% [markdown]
# Try all houses together

# %%
theories = [["Moon sign_num", "Moon position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Moon sign_num', 'Moon position'], dtype='object')
# Theory 1 score:0.4533459000942507
# Feature importances:
# Latitude: 0.3995696390383728
# Longitude: 0.3711026645825403
# BigEarthquake: 0.06640474954988243
# Moon sign_num: 0.16292294682920452

# %%
theories = [["Moon sign_num", "Mars sign_num"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Moon sign_num', 'Mars sign_num'], dtype='object')
# Theory 1 score:0.4429783223374175
# Feature importances:
# Latitude: 0.4493217833503738
# Longitude: 0.407581963617069
# Seventh House sign_num: 0.163509681657272
# Seventh House position: 0.157175019580634
# Seventh House abs_pos: 0.0
# Theory 8 score:0.24222431668237512
# Feature importances:
# Latitude: 0.3251504907106053
# Longitude: 0.30549413433054146
# BigEarthquake: 0.00763811015567456
# Eighth House quality: 0.010250783763198096
# Eighth House element: 0.01479962957336429
# Eighth House sign: 0.013396550475937003
# Eighth House sign_num: 0.16517472979175524
# Eighth House position: 0.15809557119892415
# Eighth House abs_pos: 0.0
# Theory 9 score:0.2525918944392083
# Feature importances:
# Latitude: 0.32500629266843467
# Longitude: 0.3091053211808522
# BigEarthquake: 0.007099398218339793
# Ninth House quality: 0.00942368013683395
# Ninth House element: 0.01346674980830007
# Ninth House sign: 0.012501195703173106
# Ninth House sign_num: 0.16377932965621605
# Ninth House position: 0.15961803262785018
# Ninth House abs_pos: 0.0
# Theory 10 score:0.2780395852968897
# Feature importances:
# Latitude: 0.3280961969426544
# Longitude: 0.3118125755116945
# BigEarthquake: 0.007112390497097567
# Tenth House quality: 0.009357937513655741
# Tenth House element: 0.012715204808821939
# Tenth House sign: 0.012142262330842724
# Tenth House sign_num: 0.1631776800916823
# Tenth House position: 0.15558575230355098
# Tenth House abs_pos: 0.0
# Theory 11 score:0.2714420358152686
# Feature importances:
# Latitude: 0.3185530477482411
# Longitude: 0.3214843169655741
# BigEarthquake: 0.007234019502591581
# Eleventh House quality: 0.00924296723671394
# Eleventh House element: 0.012638910059704363
# Eleventh House sign: 0.012087131654801414
# Eleventh House sign_num: 0.16259315079002956
# Eleventh House position: 0.15616645604234397
# Eleventh House abs_pos: 0.0
# Theory 12 score:0.27238454288407166
# Feature importances:
# Latitude: 0.3295018382185605
# Longitude: 0.3082888588278714
# BigEarthquake: 0.007574857972802833
# Twelfth House quality: 0.009605663944870581
# Twelfth House element: 0.013509647349784538
# Twelfth House sign: 0.01285314237032826
# Twelfth House sign_num: 0.16251988491708252
# Twelfth House position: 0.1561461063986994
# Twelfth House abs_pos: 0.0

# %% [markdown]
# Individual houses seem to linger betweeg 25-30%. Let's try their best features. Then, we'll combine that with Mars (and maybe other planets).

# %%
theories = [["House sign_num"],
            ["House position"],
            ["House sign_num", "House position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 score:0.23845428840716307
# Feature importances:
# Latitude: 0.4807609318793888
# Longitude: 0.4837860375968024
# BigEarthquake: 0.0028441592306332505
# First House sign_num: 0.0032203111931359304
# Second House sign_num: 0.003023442044595706
# Third House sign_num: 0.002459541778792835
# Fourth House sign_num: 0.003093388610949216
# Fifth House sign_num: 0.0031851649222773273
# Sixth House sign_num: 0.0026222155815639435
# Seventh House sign_num: 0.0031718404113885473
# Eighth House sign_num: 0.0030341170470892225
# Ninth House sign_num: 0.002566353336364641
# Tenth House sign_num: 0.003043585382715646
# Eleventh House sign_num: 0.0031889109843025723
# Theory 2 score:0.13666352497643733
# Feature importances:
# Latitude: 0.17864328532263396
# Longitude: 0.17618867361726065
# BigEarthquake: 0.05347434071095135
# First House position: 0.054009317223800826
# Second House position: 0.053444328136035925
# Third House position: 0.05354124285023951
# Fourth House position: 0.05375680985861666
# Fifth House position: 0.054018108384798785
# Sixth House position: 0.05332879170585399
# Seventh House position: 0.05397796070819201
# Eighth House position: 0.05348818740522152
# Ninth House position: 0.053743357135546566
# Tenth House position: 0.054357975294460036
# Eleventh House position: 0.05402762164638815
# Theory 3 score:0.10179076343072573
# Feature importances:
# Latitude: 0.16118566339100265
# Longitude: 0.16153809545831385
# BigEarthquake: 0.0037358937192460318
# First House sign_num: 0.05328831370165076
# First House position: 0.003775980932177821
# Second House sign_num: 0.05361363568977017
# Second House position: 0.003914063217055354
# Third House sign_num: 0.0534629102263732
# Third House position: 0.0036896800985329707
# Fourth House sign_num: 0.05222349784725197
# Fourth House position: 0.0034704758059339955
# Fifth House sign_num: 0.05149285935468888
# Fifth House position: 0.003601529750191928
# Sixth House sign_num: 0.052536367748781655
# Sixth House position: 0.0037186512480591534
# Seventh House sign_num: 0.05205355850691904
# Seventh House position: 0.003658473429258297
# Eighth House sign_num: 0.05355516340213888
# Eighth House position: 0.003498233834096741
# Ninth House sign_num: 0.051969132478585374
# Ninth House position: 0.0036982860849822095
# Tenth House sign_num: 0.052297878335961695
# Tenth House position: 0.0036655211921201437
# Eleventh House sign_num: 0.05372346954831625
# Eleventh House position: 0.003913587216828215
# Twelfth House sign_num: 0.05271907778176271

# %%
theories = [["First House sign_num" ,"First House position"],
            ["Second House sign_num" ,"Second House position"],
            ["Third House sign_num" ,"Third House position"],
            ["Fourth House sign_num" ,"Fourth House position"],
            ["Fifth House sign_num" ,"Fifth House position"],
            ["Sixth House sign_num" ,"Sixth House position"],
            ["Seventh House sign_num" ,"Seventh House position"],
            ["Eighth House sign_num" ,"Eighth House position"],
            ["Ninth House sign_num" ,"Ninth House position"],
            ["Tenth House sign_num" ,"Tenth House position"],
            ["Eleventh House sign_num" ,"Eleventh House position"],
            ["Twelfth House sign_num" ,"Twelfth House position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'First House sign_num',
#        'First House position'],
#       dtype='object')
# Theory 1 score:0.41564561734213007
# Feature importances:
# Latitude: 0.4037476952238371
# Longitude: 0.36697492957635414
# BigEarthquake: 0.06558987233774811
# First House sign_num: 0.16368750286206066
# Theory 2 columns:Index(['Latitude', 'Longitude', 'Second House sign_num',
#        'Second House position'],
#       dtype='object')
# Theory 2 score:0.39491046182846373
# Feature importances:
# Latitude: 0.406629744320508
# Longitude: 0.3655908736597581
# BigEarthquake: 0.06541863305081862
# Second House sign_num: 0.1623607489689152
# Theory 3 columns:Index(['Latitude', 'Longitude', 'Third House sign_num',
#        'Third House position'],
#       dtype='object')
# Theory 3 score:0.41658812441093307
# Feature importances:
# Latitude: 0.40279961308058587
# Longitude: 0.3713874818569351
# BigEarthquake: 0.06484284834056346
# Third House sign_num: 0.16097005672191567
# Theory 4 columns:Index(['Latitude', 'Longitude', 'Fourth House sign_num',
#        'Fourth House position'],
#       dtype='object')
# Theory 4 score:0.40999057492931196
# Feature importances:
# Latitude: 0.4091382881526273
# Longitude: 0.3596676360912082
# BigEarthquake: 0.06447998397886069
# Fourth House sign_num: 0.16671409177730379
# Theory 5 columns:Index(['Latitude', 'Longitude', 'Fifth House sign_num',
#        'Fifth House position'],
#       dtype='object')
# Theory 5 score:0.43166823751178135
# Feature importances:
# Latitude: 0.40988494018647553
# Longitude: 0.3632590484830682
# BigEarthquake: 0.06573577154495795
# Fifth House sign_num: 0.16112023978549833
# Theory 6 columns:Index(['Latitude', 'Longitude', 'Sixth House sign_num',
#        'Sixth House position'],
#       dtype='object')
# Theory 6 score:0.3977379830348728
# Feature importances:
# Latitude: 0.40337056708520375
# Longitude: 0.37077537691488555
# BigEarthquake: 0.0638949545750461
# Sixth House sign_num: 0.16195910142486458
# Theory 7 columns:Index(['Latitude', 'Longitude', 'Seventh House sign_num',
#        'Seventh House position'],
#       dtype='object')
# Theory 7 score:0.412818096135721
# Feature importances:
# Latitude: 0.40264396504928723
# Longitude: 0.3727148898660712
# BigEarthquake: 0.06172720985655748
# Seventh House sign_num: 0.1629139352280841
# Theory 8 columns:Index(['Latitude', 'Longitude', 'Eighth House sign_num',
#        'Eighth House position'],
#       dtype='object')
# Theory 8 score:0.4175306314797361
# Feature importances:
# Latitude: 0.4022240793640329
# Longitude: 0.36714583892074537
# BigEarthquake: 0.06512680882179872
# Eighth House sign_num: 0.16550327289342304
# Theory 9 columns:Index(['Latitude', 'Longitude', 'Ninth House sign_num',
#        'Ninth House position'],
#       dtype='object')
# Theory 9 score:0.42412818096135724
# Feature importances:
# Latitude: 0.4026465474963855
# Longitude: 0.3706311677880704
# BigEarthquake: 0.06410006593700542
# Ninth House sign_num: 0.1626222187785386
# Theory 10 columns:Index(['Latitude', 'Longitude', 'Tenth House sign_num',
#        'Tenth House position'],
#       dtype='object')
# Theory 10 score:0.41658812441093307
# Feature importances:
# Latitude: 0.39992339672552835
# Longitude: 0.3707297540566397
# BigEarthquake: 0.06654324747420544
# Tenth House sign_num: 0.16280360174362665
# Theory 11 columns:Index(['Latitude', 'Longitude', 'Eleventh House sign_num',
#        'Eleventh House position'],
#       dtype='object')
# Theory 11 score:0.41564561734213007
# Feature importances:
# Latitude: 0.39785772125330077
# Longitude: 0.3761054286061584
# BigEarthquake: 0.0651375233348247
# Eleventh House sign_num: 0.16089932680571611
# Theory 12 columns:Index(['Latitude', 'Longitude', 'Twelfth House sign_num',
#        'Twelfth House position'],
#       dtype='object')
# Theory 12 score:0.4071630537229029
# Feature importances:
# Latitude: 0.4028431435951307
# Longitude: 0.37012720892410206
# BigEarthquake: 0.06670995762273552
# Twelfth House sign_num: 0.1603196898580318

# %% [markdown]
# Individual houses seem to perform good with sign_num; around 40%. But sign_num contribution is not more than 0.16. Let's combine them.

# %%
theories = [["House sign_num"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'First House sign_num',
#        'Second House sign_num', 'Third House sign_num',
#        'Fourth House sign_num', 'Fifth House sign_num', 'Sixth House sign_num',
#        'Seventh House sign_num', 'Eighth House sign_num',
#        'Ninth House sign_num', 'Tenth House sign_num',
#        'Eleventh House sign_num', 'Twelfth House sign_num'],
#       dtype='object')
# Theory 1 score:0.24222431668237512
# Feature importances:
# Latitude: 0.47987393465146205
# Longitude: 0.48530730899457664
# BigEarthquake: 0.00276762154916791
# First House sign_num: 0.0031544239404337677
# Second House sign_num: 0.002830508797795046
# Third House sign_num: 0.0026221460864177242
# Fourth House sign_num: 0.002855899194833715
# Fifth House sign_num: 0.0030298560959899174
# Sixth House sign_num: 0.00279132212090213
# Seventh House sign_num: 0.0030909558755595813
# Eighth House sign_num: 0.0029527832358624477
# Ninth House sign_num: 0.0024446741765170566
# Tenth House sign_num: 0.002974956286284533
# Eleventh House sign_num: 0.0033036089941973906

# %% [markdown]
# Score decreased. Let's try to combine the best houses only.

# %%
theories = [["Tenth House sign_num" ,"Eleventh House sign_num"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Tenth House sign_num',
#        'Eleventh House sign_num'],
#       dtype='object')
# Theory 1 score:0.43826578699340246
# Feature importances:
# Latitude: 0.4738492916901213
# Longitude: 0.44709119521973906
# BigEarthquake: 0.039892764489038675
# Tenth House sign_num: 0.039166748601100955

# %%
theories = [["Tenth House position" ,"Eleventh House position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Tenth House position',
#        'Eleventh House position'],
#       dtype='object')
# Theory 1 score:0.41470311027332707
# Feature importances:
# Latitude: 0.37599497542364774
# Longitude: 0.3506143292660165
# BigEarthquake: 0.13758497950546283
# Tenth House position: 0.13580571580487288

# %%
theories = [["Tenth House sign_num",
             "Tenth House position",
             "Eleventh House sign_num",
             "Eleventh House position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Tenth House sign_num', 'Tenth House position',
#        'Eleventh House sign_num', 'Eleventh House position'],
#       dtype='object')
# Theory 1 score:0.2629594721960415
# Feature importances:
# Latitude: 0.3298710213523709
# Longitude: 0.3031198448376245
# BigEarthquake: 0.032902861908253735
# Tenth House sign_num: 0.1504392767181031
# Tenth House position: 0.03357238384101067
# Eleventh House sign_num: 0.15009461134263705

# %%
theories = [["Fifth House sign_num" ,"Fifth House position"],
            ["Fifth House sign_num"],
            ["Fifth House position"]]
run_theories(df, features, theories)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Fifth House sign_num',
#        'Fifth House position'],
#       dtype='object')
# Theory 1 score:0.4533459000942507
# Feature importances:
# Latitude: 0.4038652514826006
# Longitude: 0.3707574946295397
# BigEarthquake: 0.06574154171856886
# Fifth House sign_num: 0.15963571216929096
# Theory 2 columns:Index(['Latitude', 'Longitude', 'Fifth House sign_num'], dtype='object')
# Theory 2 score:0.39491046182846373
# Feature importances:
# Latitude: 0.4914160764438474
# Longitude: 0.4855066853342911
# BigEarthquake: 0.023077238221861508
# Theory 3 columns:Index(['Latitude', 'Longitude', 'Fifth House position'], dtype='object')
# Theory 3 score:0.3685202639019793
# Feature importances:
# Latitude: 0.3961061650728919
# Longitude: 0.38674983377015204
# BigEarthquake: 0.21714400115695595

# %% [markdown]
# ## Random combo of sign_num, position features

# %%
import random

features = ["Latitude", 
            "Longitude",
            "BigEarthquake"]

suffixes = ["sign_num", "position"]

planets = ["Sun",
           "Moon",
           "Mercury",
           "Venus",
           "Mars",
           "Jupiter",
           "Saturn",
           "Uranus",
           "Neptune",
           "Pluto"]

houses = ["First House",
          "Second House",
          "Third House",
          "Fourth House",
          "Fifth House",
          "Sixth House",
          "Seventh House",
          "Eighth House",
          "Ninth House",
          "Tenth House",
          "Eleventh House",
          "Twelfth House"]

def build_and_run_theories(max_attempt, max_feature_count):
    attempt = 0
    theories = []

    while attempt < max_attempt:
        attempt += 1
        planets_copy = planets.copy()
        houses_copy = houses.copy()
        feature_count = random.randint(0, max_feature_count)
        theory = []

        while len(theory) < feature_count:
            cat = random.randint(0, 1)

            if cat == 0:
                catd = planets_copy
            else:
                catd = houses_copy

            if len(catd) <= 0:
                continue

            catd_pos = random.randint(0, len(catd)-1)
            feature_prefix = catd.pop(catd_pos)
            
            suf = random.randint(0, len(suffixes)-1)
            suffix = suffixes[suf]
            theory.append(feature_prefix + " " + suffix)

        theories.append(theory)

    run_theories(df, features, theories)

# %% [markdown]
# Apparently, too many features reduce the output quality. I will try with lesser features.

# %%
build_and_run_theories(5, 7)
# Out:
# Theory 1 columns:Index(['Latitude', 'Longitude', 'Mercury sign_num', 'Mars sign_num',
#        'Jupiter sign_num'],
#       dtype='object')
# Theory 1 score:0.37983034872761545
# Feature importances:
# Latitude: 0.40551268427027287
# Longitude: 0.38014011304239587
# BigEarthquake: 0.07585812673408589
# Mercury sign_num: 0.07087872816489416
# Mars sign_num: 0.06761034778835118
# Theory 2 columns:Index(['Latitude', 'Longitude', 'Uranus position', 'Seventh House sign_num',
#        'Tenth House sign_num'],
#       dtype='object')
# Theory 2 score:0.353440150801131
# Feature importances:
# Latitude: 0.3688803962213401
# Longitude: 0.3569065052733539
# BigEarthquake: 0.19385857880072932
# Uranus position: 0.04044453572282599
# Seventh House sign_num: 0.03990998398175078
# Theory 3 columns:Index(['Latitude', 'Longitude', 'Mercury position', 'Saturn sign_num',
#        'First House sign_num', 'Sixth House position'],
#       dtype='object')
# Theory 3 score:0.29123468426013194
# Feature importances:
# Latitude: 0.3108398809734597
# Longitude: 0.2905094448086158
# BigEarthquake: 0.14568417859855454
# Mercury position: 0.05245775141648234
# Saturn sign_num: 0.060929703869661865
# First House sign_num: 0.13957904033322574
# Theory 4 columns:Index(['Latitude', 'Longitude', 'Moon position', 'Fifth House position'], dtype='object')
# Theory 4 score:0.42601319509896324
# Feature importances:
# Latitude: 0.382179937781424
# Longitude: 0.34311223174387667
# BigEarthquake: 0.14017721690374454
# Moon position: 0.13453061357095464
# Theory 5 columns:Index(['Latitude', 'Longitude'], dtype='object')
# Theory 5 score:0.5080113100848256
# Feature importances:
# Latitude: 0.5079605172124535
# Longitude: 0.4920394827875465

# %% [markdown]
# <hr>

# %% [markdown]
# # Experimentation
